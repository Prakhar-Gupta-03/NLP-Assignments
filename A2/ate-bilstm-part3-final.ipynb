# %%
import json
import pandas as pd
import numpy as np
import re
import string


ate_train  = json.load(open('/kaggle/input/json-data-ate/ATE_train.json'))
ate_test = json.load(open('/kaggle/input/json-data-ate/ATE_test.json'))
ate_val = json.load(open('/kaggle/input/json-data-ate/ATE_val.json'))
# ate_train_csv = {}
# ate_test_csv = {}
sentence = []
Tag = []
Words = []
count = 0
for i in ate_train:

    for j in ate_train[i]['label']:
        sentence.append(str(count))
        Tag.append(j)
    for j in ate_train[i]['text']:
        Words.append(j)
    count+=1
ate_train_csv = {"Sentence #":sentence,"Word":Words,"Tag":Tag}
print(len(sentence),len(Words),len(Tag))
# save this as csv file
df = pd.DataFrame(ate_train_csv)
df.to_csv('ate_train.csv',index=False)

sentence = []
Tag = []
Words = []
count = 0
for i in ate_test:

    for j in ate_test[i]['label']:
        sentence.append(str(count))
        Tag.append(j)
    for j in ate_test[i]['text']:
        Words.append(j)
    count+=1
ate_test_csv = {"Sentence #":sentence,"Word":Words,"Tag":Tag}
print(len(sentence),len(Words),len(Tag))
# save this as csv file
df = pd.DataFrame(ate_test_csv)
df.to_csv('ate_test.csv',index=False)

sentence = []
Tag = []
Words = []
count = 0
for i in ate_val:

    for j in ate_val[i]['label']:
        sentence.append(str(count))
        Tag.append(j)
    for j in ate_val[i]['text']:
        Words.append(j)
    count+=1
ate_val_csv = {"Sentence #":sentence,"Word":Words,"Tag":Tag}
print(len(sentence),len(Words),len(Tag))
# save this as csv file
df = pd.DataFrame(ate_val_csv)
df.to_csv('ate_val.csv',index=False)
# Out:
# 17354 17354 17354
# 5171 5171 5171
# 4175 4175 4175

# %%
test_data = pd.read_csv("/kaggle/working/ate_test.csv")
data = pd.read_csv("/kaggle/working/ate_train.csv")
val_data = pd.read_csv("/kaggle/working/ate_val.csv")
# print(len(data))
words = []

# %%
# print(data.head())
words = []
count = 0
def remove_punct(word):
    pun = list(".,()-:;?!")
    try:
        for i in pun:
            if i in word:
#                 print(i)
                word = word.replace(i,"")
    except:
        word = word
#     print(word)
    return word       
for i in data['Word']:
    words.append(remove_punct(i))

# %%
print(len(words),len(data))
data['Word'] = words
# Out:
# 17354 17354

# %%
data['Tag'].value_counts()
# Out:
# O    15489
# B     1281
# I      584
# Name: Tag, dtype: int64

# %%
# data.head(1)

# %%
class SentenceGetter(object):
    
    def __init__(self, dataset):
        self.n_sent = 1
        self.dataset = dataset
        self.empty = False
        agg_func = lambda s: [(w, t) for w,t in zip(s["Word"].values.tolist(),
                                                        s["Tag"].values.tolist())]
        self.grouped = self.dataset.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None
          
getter = SentenceGetter(data)
sentences = getter.sentences

test_getter = SentenceGetter(test_data)
test_sentences = test_getter.sentences
print(len(test_sentences),len(sentences))

val_getter = SentenceGetter(val_data)
val_sentences = test_getter.sentences
# Out:
# 328 906

# %%
from math import nan
# temp_data = data+test_data
words = list(set(data["Word"].values))
test_words = list(set(test_data['Word'].values))
words = set(words+test_words)
n_words = len(words)

tags = []
for tag in set(data["Tag"].values):
    if tag is nan or isinstance(tag, float):
        tags.append('unk')
    else:
        tags.append(tag)
n_tags = len(tags)

# %% [markdown]
# ## Prepare the data
# Now we introduce dictionaries of words and tags.

# %%
from future.utils import iteritems


word2idx = {w: i for i, w in enumerate(words)}
idx2word = {i:w for w, i in word2idx.items()}
tag2idx = {t: i for i, t in enumerate(tags)}
idx2tag = {v: k for k, v in iteritems(tag2idx)}

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

maxlen = max([len(s) for s in sentences])

X = [[word2idx[w[0]] for w in s] for s in sentences]
X_train = pad_sequences(maxlen=maxlen, sequences=X, padding="post",value=n_words - 1)

y = [[tag2idx[w[1]] for w in s] for s in sentences]
y = pad_sequences(maxlen=maxlen, sequences=y, padding="post", value=tag2idx["O"])
y_train = [to_categorical(i, num_classes=n_tags) for i in y]
X_test = [[word2idx[w[0]] for w in s] for s in test_sentences]
print(len(X_test))
X_test = pad_sequences(maxlen=maxlen, sequences=X_test, padding="post",value=n_words - 1) 

y_test = [[tag2idx[w[1]] for w in s] for s in test_sentences]
print(len(y_test))
y_test = pad_sequences(maxlen=maxlen, sequences=y_test, padding="post", value=tag2idx["O"])
y_test = [to_categorical(i, num_classes=n_tags) for i in y_test]
print(len(y_test))


X_val = [[word2idx[w[0]] for w in s] for s in val_sentences]
print(len(X_val))
X_val = pad_sequences(maxlen=maxlen, sequences=X_val, padding="post",value=n_words - 1) 

y_val = [[tag2idx[w[1]] for w in s] for s in val_sentences]
print(len(y_val))
y_val = pad_sequences(maxlen=maxlen, sequences=y_val, padding="post", value=tag2idx["O"])
y_val = [to_categorical(i, num_classes=n_tags) for i in y_val]
print(len(y_test))
# Split train and test data
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# X_train = data['Word']
# y_train = data['Tag']

# X_test = test_data['Word']
# y_test = test_data['Tag']

print(len(X_test),len(X_train))
import joblib

joblib.dump((X_test, y_test), 'test_data_ate.pkl')
# Out:
# 328
# 328
# 328
# 328
# 328
# 328
# 328 906
# ['test_data_ate.pkl']

# %% [markdown]
# ## Setup the CRF-BILSTM

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-ghiog0bs
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-ghiog0bs
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (5.1.2)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.13.0)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.3.3)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.17.4)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101065 sha256=742dc7f3918fafc842e5e2adf575f684f9559c7d9658b61c39f6792797ecdc2e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wpciofz1/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
# Collecting sklearn_crfsuite
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/5e/c5/ec8156ea62dd45df5ef05510281e8b72795a956914d8c12694c0c08f7373/python_crfsuite-0.9.10-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 4.1MB/s eta 0:00:01
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.6/site-packages/tabulate-0.8.6-py3.6.egg (from sklearn_crfsuite) (0.8.6)
# Requirement already satisfied: tqdm>=2.0 in /opt/conda/lib/python3.6/site-packages (from sklearn_crfsuite) (4.39.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from sklearn_crfsuite) (1.13.0)
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.10 sklearn-crfsuite-0.3.6

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF

# %%
print(k.__version__)
# Out:
# 2.3.1

# %% [markdown]
# ## F1 MACRO

# %%
from tensorflow.keras.callbacks import Callback
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite.utils import flatten
from sklearn.metrics import f1_score

def F1_Score(y_test,y_pred):
    y_test = np.argmax(y_test, axis=2)
    # Flatten y_pred if necessary
    if y_pred.ndim == 3:
        y_pred = np.argmax(y_pred, axis=2)
    classes = np.unique(y_test)
    precision = []
    recall = []
    f1 = []
    for c in classes:
        tp = np.sum((y_test == c) & (y_pred == c))
        fp = np.sum((y_test != c) & (y_pred == c))
        fn = np.sum((y_test == c) & (y_pred != c))
        
        precision_c = tp / (tp + fp) if tp + fp > 0 else 0
        recall_c = tp / (tp + fn) if tp + fn > 0 else 0
        f1_c = 2 * (precision_c * recall_c) / (precision_c + recall_c) if precision_c + recall_c > 0 else 0
        
        precision.append(precision_c)
        recall.append(recall_c)
        f1.append(f1_c)

    macro_precision = np.mean(precision)
    macro_recall = np.mean(recall)
    macro_f1 = np.mean(f1)

    return macro_f1

class F1ScoreCallback(Callback):
    def __init__(self, X_train, y_train, X_val, y_val):
        self.X_train = X_train
        self.y_train = y_train
        self.X_val = X_val
        self.y_val = y_val

    def on_epoch_end(self, epoch, logs={}):
        # Predict on training and validation sets
        y_train_pred = np.argmax(self.model.predict(self.X_train), axis=-1)
        y_val_pred = np.argmax(self.model.predict(self.X_val), axis=-1)

        # Calculate F1 scores for training and validation sets
        f1_train = F1_Score(self.y_train, y_train_pred)
        f1_val = F1_Score(self.y_val, y_val_pred)



#         print(f' - F1 Score (train): {f1_train:.4f}')
#         print(f' - F1 Score (val): {f1_val:.4f}')

#         # Log F1 scores to the logs dictionary (for logging with Keras)
        if logs is not None:
            logs['f1_score_train'] = f1_train
            logs['f1_score_val'] = f1_val

        # Print F1 scores
        print(f' - f1_train: {f1_train:.4f} - f1_val: {f1_val:.4f}')
f1_callback = F1ScoreCallback(X_train, np.array(y_train), X_val, np.array(y_val))

# %% [markdown]
# ## GLOVE

# %%
input = Input(shape=(1,))
word_embedding_size = 10

embedding_path = '/kaggle/input/glove6b100dtxt/glove.6B.100d.txt'
embedding_dim = 100
def load_glove_embeddings(embedding_path, embedding_dim, word_index):
    embeddings_index = {}
    with open(embedding_path, encoding='utf-8') as f:
        print(f)
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs

    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
    return embedding_matrix

embedding_matrix = load_glove_embeddings(embedding_path, embedding_dim, word2idx)
# Out:
# <_io.TextIOWrapper name='/kaggle/input/glove6b100dtxt/glove.6B.100d.txt' mode='r' encoding='utf-8'>

# %%
from keras.models import Model, Input,Sequential
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF
m = 78
# m = 76
input = Input(shape=(m,))
word_embedding_size = 100
model = Sequential()
model.add(Embedding(input_dim=n_words+1, output_dim=100, input_length=m, weights=[embedding_matrix]))
# model.add(Dropout(0.1))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.01)))

model.add(TimeDistributed(Dense(n_tags)))
# model.add(Activation('relu'))
crf = CRF(n_tags)
model.add(crf)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 78, 100)           318200
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 78, 200)           160800
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 78, 3)             603
# _________________________________________________________________
# crf_1 (CRF)                  (None, 78, 3)             27
# =================================================================
# Total params: 479,630
# Trainable params: 479,630
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.01, beta_1=0.5, beta_2=0.5)

# # Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])


# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=128, epochs=20, validation_data = (X_val,np.array(y_val)), verbose=1,callbacks=[f1_callback])


# Assuming `model` is your Keras model
# Save the model
model.save('glove_ate_3.h5')
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 906 samples, validate on 328 samples
# Epoch 1/20
# 906/906 [==============================] - 4s 5ms/step - loss: 0.3136 - crf_viterbi_accuracy: 0.8720 - accuracy: 0.0181 - val_loss: 0.0858 - val_crf_viterbi_accuracy: 0.9739 - val_accuracy: 0.9741
#  - f1_train: 0.4704 - f1_val: 0.4345
# Epoch 2/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0786 - crf_viterbi_accuracy: 0.9760 - accuracy: 0.0181 - val_loss: 0.0672 - val_crf_viterbi_accuracy: 0.9779 - val_accuracy: 0.9783
#  - f1_train: 0.6467 - f1_val: 0.5853
# Epoch 3/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0529 - crf_viterbi_accuracy: 0.9841 - accuracy: 0.0181 - val_loss: 0.0586 - val_crf_viterbi_accuracy: 0.9821 - val_accuracy: 0.9826
#  - f1_train: 0.8336 - f1_val: 0.6996
# Epoch 4/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0416 - crf_viterbi_accuracy: 0.9872 - accuracy: 0.0181 - val_loss: 0.0594 - val_crf_viterbi_accuracy: 0.9807 - val_accuracy: 0.9815
#  - f1_train: 0.8558 - f1_val: 0.7612
# Epoch 5/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0327 - crf_viterbi_accuracy: 0.9906 - accuracy: 0.0181 - val_loss: 0.0589 - val_crf_viterbi_accuracy: 0.9815 - val_accuracy: 0.9822
#  - f1_train: 0.8888 - f1_val: 0.6749
# Epoch 6/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0247 - crf_viterbi_accuracy: 0.9931 - accuracy: 0.0181 - val_loss: 0.0590 - val_crf_viterbi_accuracy: 0.9822 - val_accuracy: 0.9828
#  - f1_train: 0.9005 - f1_val: 0.6840
# Epoch 7/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0193 - crf_viterbi_accuracy: 0.9948 - accuracy: 0.0181 - val_loss: 0.0615 - val_crf_viterbi_accuracy: 0.9827 - val_accuracy: 0.9835
#  - f1_train: 0.9493 - f1_val: 0.7081
# Epoch 8/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0138 - crf_viterbi_accuracy: 0.9963 - accuracy: 0.0181 - val_loss: 0.0564 - val_crf_viterbi_accuracy: 0.9838 - val_accuracy: 0.9842
#  - f1_train: 0.9536 - f1_val: 0.7776
# Epoch 9/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0106 - crf_viterbi_accuracy: 0.9976 - accuracy: 0.0181 - val_loss: 0.0563 - val_crf_viterbi_accuracy: 0.9841 - val_accuracy: 0.9847
#  - f1_train: 0.9838 - f1_val: 0.7703
# Epoch 10/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0070 - crf_viterbi_accuracy: 0.9985 - accuracy: 0.0181 - val_loss: 0.0660 - val_crf_viterbi_accuracy: 0.9834 - val_accuracy: 0.9842
#  - f1_train: 0.9880 - f1_val: 0.7657
# Epoch 11/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0043 - crf_viterbi_accuracy: 0.9990 - accuracy: 0.0181 - val_loss: 0.0918 - val_crf_viterbi_accuracy: 0.9817 - val_accuracy: 0.9826
#  - f1_train: 0.9687 - f1_val: 0.7044
# Epoch 12/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0033 - crf_viterbi_accuracy: 0.9990 - accuracy: 0.0181 - val_loss: 0.0755 - val_crf_viterbi_accuracy: 0.9836 - val_accuracy: 0.9843
#  - f1_train: 0.9950 - f1_val: 0.7594
# Epoch 13/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0011 - crf_viterbi_accuracy: 0.9994 - accuracy: 0.0181 - val_loss: 0.0869 - val_crf_viterbi_accuracy: 0.9838 - val_accuracy: 0.9844
#  - f1_train: 0.9952 - f1_val: 0.7413
# Epoch 14/20
# 906/906 [==============================] - 2s 2ms/step - loss: -6.8052e-04 - crf_viterbi_accuracy: 0.9997 - accuracy: 0.0181 - val_loss: 0.0920 - val_crf_viterbi_accuracy: 0.9844 - val_accuracy: 0.9851
#  - f1_train: 0.9969 - f1_val: 0.7533
# Epoch 15/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0020 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.1105 - val_crf_viterbi_accuracy: 0.9832 - val_accuracy: 0.9840
#  - f1_train: 0.9851 - f1_val: 0.7122
# Epoch 16/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0027 - crf_viterbi_accuracy: 0.9995 - accuracy: 0.0181 - val_loss: 0.0828 - val_crf_viterbi_accuracy: 0.9833 - val_accuracy: 0.9839
#  - f1_train: 0.9975 - f1_val: 0.7643
# Epoch 17/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0044 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.0965 - val_crf_viterbi_accuracy: 0.9839 - val_accuracy: 0.9845
#  - f1_train: 0.9843 - f1_val: 0.7815
# Epoch 18/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0044 - crf_viterbi_accuracy: 0.9994 - accuracy: 0.0181 - val_loss: 0.1092 - val_crf_viterbi_accuracy: 0.9832 - val_accuracy: 0.9840
#  - f1_train: 0.9882 - f1_val: 0.7168
# Epoch 19/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0061 - crf_viterbi_accuracy: 0.9997 - accuracy: 0.0181 - val_loss: 0.0926 - val_crf_viterbi_accuracy: 0.9841 - val_accuracy: 0.9847
#  - f1_train: 0.9993 - f1_val: 0.7466
# Epoch 20/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0076 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.0843 - val_crf_viterbi_accuracy: 0.9847 - val_accuracy: 0.9850
#  - f1_train: 0.9987 - f1_val: 0.7721

# %%
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['f1_score_train']
    val_accuracy = history.history['f1_score_val']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation F1 score')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
from tensorflow.keras.models import load_model
from keras.models import load_model

def create_custom_objects():
    instanceHolder = {"instance": None}
    class ClassWrapper(CRF):
        def __init__(self, *args, **kwargs):
            instanceHolder["instance"] = self
            super(ClassWrapper, self).__init__(*args, **kwargs)
    def loss(*args):
        method = getattr(instanceHolder["instance"], "loss_function")
        return method(*args)
    def accuracy(*args):
        method = getattr(instanceHolder["instance"], "accuracy")
        return method(*args)
    return {"ClassWrapper": ClassWrapper ,"CRF": ClassWrapper, "crf_loss": loss, "crf_viterbi_accuracy":accuracy}

def load_keras_model(path):
    model = load_model(path, custom_objects=create_custom_objects())
    return model

model = load_keras_model('/kaggle/working/glove_ate_3.h5')

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
print(len(X_test))
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 328
# 328/328 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            B       0.70      0.77      0.73       463
#            I       0.67      0.53      0.59       243
#            O       0.99      0.99      0.99     24878
#
#     accuracy                           0.98     25584
#    macro avg       0.79      0.76      0.77     25584
# weighted avg       0.98      0.98      0.98     25584

# %%
# ! pip install seqeval

# %% [markdown]
# ## WORD2VEC

# %%
from gensim.models import KeyedVectors
from tqdm import tqdm
input = Input(shape=(76,))
word_embedding_size = 150
embedding_dim = 300
print("here")
word2vec_path = "/kaggle/input/googlenewsvectorsnegative300/GoogleNews-vectors-negative300.bin"  # Replace this with the path to your Word2Vec model

def load_word2vec_embeddings(word2vec_path, embedding_dim, word_index):
    word2vec_model = KeyedVectors.load_word2vec_format(word2vec_path, binary=True)
    print("loading done")
    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
    for word, i in tqdm(word_index.items()):
        if word in word2vec_model:
            embedding_matrix[i] = word2vec_model[word]

    return embedding_matrix

embedding_matrix = load_word2vec_embeddings(word2vec_path, embedding_dim, word2idx)
# Out:
# here
# 100%|██████████| 3181/3181 [00:00<00:00, 103232.52it/s]
# loading done

# %%
m = 78
# m = 76
input = Input(shape=(m,))
word_embedding_size = 100
model = Sequential()
model.add(Embedding(input_dim=n_words+1, output_dim=300, input_length=m, weights=[embedding_matrix]))
# model.add(Dropout(0.1))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.01)))

model.add(TimeDistributed(Dense(n_tags)))
# model.add(Activation('relu'))
crf_layer = CRF(n_tags)
model.add(crf_layer)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.01, beta_1=0.5, beta_2=0.5)

# # Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])


# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=128, epochs=20, validation_data= (X_val,np.array(y_val)), verbose=1,callbacks=[f1_callback])

model.save('word2vec_ate_3.h5')
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 906 samples, validate on 328 samples
# Epoch 1/20
# 906/906 [==============================] - 4s 4ms/step - loss: 0.1930 - crf_viterbi_accuracy: 0.8558 - accuracy: 0.0181 - val_loss: 0.0665 - val_crf_viterbi_accuracy: 0.9730 - val_accuracy: 0.9734
#  - f1_train: 0.3835 - f1_val: 0.3780
# Epoch 2/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0384 - crf_viterbi_accuracy: 0.9823 - accuracy: 0.0181 - val_loss: 0.0428 - val_crf_viterbi_accuracy: 0.9822 - val_accuracy: 0.9828
#  - f1_train: 0.8411 - f1_val: 0.7067
# Epoch 3/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0143 - crf_viterbi_accuracy: 0.9911 - accuracy: 0.0181 - val_loss: 0.0492 - val_crf_viterbi_accuracy: 0.9816 - val_accuracy: 0.9823
#  - f1_train: 0.8588 - f1_val: 0.6843
# Epoch 4/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0065 - crf_viterbi_accuracy: 0.9936 - accuracy: 0.0181 - val_loss: 0.0407 - val_crf_viterbi_accuracy: 0.9838 - val_accuracy: 0.9845
#  - f1_train: 0.9393 - f1_val: 0.7440
# Epoch 5/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0023 - crf_viterbi_accuracy: 0.9950 - accuracy: 0.0181 - val_loss: 0.0458 - val_crf_viterbi_accuracy: 0.9809 - val_accuracy: 0.9814
#  - f1_train: 0.9663 - f1_val: 0.7377
# Epoch 6/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0066 - crf_viterbi_accuracy: 0.9973 - accuracy: 0.0181 - val_loss: 0.0418 - val_crf_viterbi_accuracy: 0.9821 - val_accuracy: 0.9826
#  - f1_train: 0.9828 - f1_val: 0.7616
# Epoch 7/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0114 - crf_viterbi_accuracy: 0.9985 - accuracy: 0.0181 - val_loss: 0.0611 - val_crf_viterbi_accuracy: 0.9796 - val_accuracy: 0.9806
#  - f1_train: 0.9888 - f1_val: 0.7257
# Epoch 8/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0134 - crf_viterbi_accuracy: 0.9990 - accuracy: 0.0181 - val_loss: 0.0624 - val_crf_viterbi_accuracy: 0.9826 - val_accuracy: 0.9832
#  - f1_train: 0.9944 - f1_val: 0.7286
# Epoch 9/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0159 - crf_viterbi_accuracy: 0.9995 - accuracy: 0.0181 - val_loss: 0.0721 - val_crf_viterbi_accuracy: 0.9791 - val_accuracy: 0.9801
#  - f1_train: 0.9963 - f1_val: 0.7254
# Epoch 10/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0172 - crf_viterbi_accuracy: 0.9995 - accuracy: 0.0181 - val_loss: 0.0695 - val_crf_viterbi_accuracy: 0.9827 - val_accuracy: 0.9833
#  - f1_train: 0.9975 - f1_val: 0.7419
# Epoch 11/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0184 - crf_viterbi_accuracy: 0.9997 - accuracy: 0.0181 - val_loss: 0.0801 - val_crf_viterbi_accuracy: 0.9791 - val_accuracy: 0.9799
#  - f1_train: 0.9977 - f1_val: 0.7239
# Epoch 12/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0195 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.0854 - val_crf_viterbi_accuracy: 0.9779 - val_accuracy: 0.9787
#  - f1_train: 0.9988 - f1_val: 0.7263
# Epoch 13/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0209 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.0894 - val_crf_viterbi_accuracy: 0.9786 - val_accuracy: 0.9792
#  - f1_train: 0.9980 - f1_val: 0.7271
# Epoch 14/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0219 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.0915 - val_crf_viterbi_accuracy: 0.9802 - val_accuracy: 0.9810
#  - f1_train: 0.9993 - f1_val: 0.7270
# Epoch 15/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0231 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.0806 - val_crf_viterbi_accuracy: 0.9799 - val_accuracy: 0.9807
#  - f1_train: 0.9994 - f1_val: 0.7453
# Epoch 16/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0242 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.0880 - val_crf_viterbi_accuracy: 0.9818 - val_accuracy: 0.9825
#  - f1_train: 0.9986 - f1_val: 0.7306
# Epoch 17/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0252 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.0885 - val_crf_viterbi_accuracy: 0.9817 - val_accuracy: 0.9823
#  - f1_train: 0.9994 - f1_val: 0.7482
# Epoch 18/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0264 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.0931 - val_crf_viterbi_accuracy: 0.9794 - val_accuracy: 0.9802
#  - f1_train: 0.9992 - f1_val: 0.7378
# Epoch 19/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0274 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.0932 - val_crf_viterbi_accuracy: 0.9821 - val_accuracy: 0.9828
#  - f1_train: 0.9986 - f1_val: 0.7407
# Epoch 20/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0285 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.0988 - val_crf_viterbi_accuracy: 0.9794 - val_accuracy: 0.9802
#  - f1_train: 0.9993 - f1_val: 0.7351

# %%
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['f1_score_train']
    val_accuracy = history.history['f1_score_val']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation F1 score')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
from tensorflow.keras.models import load_model
from keras.models import load_model

def create_custom_objects():
    instanceHolder = {"instance": None}
    class ClassWrapper(CRF):
        def __init__(self, *args, **kwargs):
            instanceHolder["instance"] = self
            super(ClassWrapper, self).__init__(*args, **kwargs)
    def loss(*args):
        method = getattr(instanceHolder["instance"], "loss_function")
        return method(*args)
    def accuracy(*args):
        method = getattr(instanceHolder["instance"], "accuracy")
        return method(*args)
    return {"ClassWrapper": ClassWrapper ,"CRF": ClassWrapper, "crf_loss": loss, "crf_viterbi_accuracy":accuracy}

def load_keras_model(path):
    model = load_model(path, custom_objects=create_custom_objects())
    return model

model = load_keras_model('/kaggle/working/word2vec_ate_3.h5')
def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
print(len(X_test))
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 328
# 328/328 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            B       0.64      0.74      0.68       463
#            I       0.51      0.55      0.53       243
#            O       0.99      0.99      0.99     24878
#
#     accuracy                           0.98     25584
#    macro avg       0.71      0.76      0.74     25584
# weighted avg       0.98      0.98      0.98     25584

# %% [markdown]
# ## Fast Text

# %%
from gensim.models import KeyedVectors
from tqdm import tqdm

word_embedding_size = 150
embedding_dim = 300

# %%
import torch
from torchtext.vocab import FastText

# Load FastText embeddings
fasttext = FastText(language='en')

# Get the embedding dimension
embedding_dim = fasttext.dim

# Initialize the embedding matrix
embedding_matrix = torch.zeros((len(word2idx) + 1, embedding_dim))

# Populate the embedding matrix
for word, idx in tqdm(word2idx.items()):
    if word in fasttext.stoi:
        embedding_matrix[idx] = fasttext[word]
# Out:
# .vector_cache/wiki.en.vec: 6.60GB [00:45, 146MB/s]
# 100%|█████████▉| 2518761/2519370 [05:23<00:00, 7858.58it/s]
# 100%|██████████| 3181/3181 [00:00<00:00, 59279.70it/s]
# 100%|█████████▉| 2518761/2519370 [05:40<00:00, 7858.58it/s]

# %%
m = 78
# m = 76
input = Input(shape=(m,))
word_embedding_size = 100
model = Sequential()
model.add(Embedding(input_dim=n_words+1, output_dim=300, input_length=m, weights=[embedding_matrix]))
# model.add(Dropout(0.1))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.01)))

model.add(TimeDistributed(Dense(n_tags)))
# model.add(Activation('relu'))
crf_layer = CRF(n_tags)
model.add(crf_layer)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.01, beta_1=0.5, beta_2=0.5)

# # Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])


# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=128, epochs=20, validation_data = (X_val,np.array(y_val)), verbose=1,callbacks=[f1_callback])

model.save('fasttext_ate_3.h5')
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 906 samples, validate on 328 samples
# Epoch 1/20
# 906/906 [==============================] - 4s 4ms/step - loss: 0.1853 - crf_viterbi_accuracy: 0.9728 - accuracy: 0.0181 - val_loss: 0.0997 - val_crf_viterbi_accuracy: 0.9722 - val_accuracy: 0.9726
#  - f1_train: 0.3513 - f1_val: 0.3386
# Epoch 2/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0583 - crf_viterbi_accuracy: 0.9806 - accuracy: 0.0181 - val_loss: 0.0554 - val_crf_viterbi_accuracy: 0.9808 - val_accuracy: 0.9815
#  - f1_train: 0.7675 - f1_val: 0.6777
# Epoch 3/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0347 - crf_viterbi_accuracy: 0.9884 - accuracy: 0.0181 - val_loss: 0.0577 - val_crf_viterbi_accuracy: 0.9817 - val_accuracy: 0.9823
#  - f1_train: 0.8166 - f1_val: 0.6331
# Epoch 4/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0234 - crf_viterbi_accuracy: 0.9928 - accuracy: 0.0181 - val_loss: 0.0609 - val_crf_viterbi_accuracy: 0.9831 - val_accuracy: 0.9837
#  - f1_train: 0.9218 - f1_val: 0.7217
# Epoch 5/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0163 - crf_viterbi_accuracy: 0.9944 - accuracy: 0.0181 - val_loss: 0.0580 - val_crf_viterbi_accuracy: 0.9771 - val_accuracy: 0.9777
#  - f1_train: 0.9442 - f1_val: 0.7147
# Epoch 6/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0108 - crf_viterbi_accuracy: 0.9964 - accuracy: 0.0181 - val_loss: 0.0565 - val_crf_viterbi_accuracy: 0.9802 - val_accuracy: 0.9810
#  - f1_train: 0.9686 - f1_val: 0.7261
# Epoch 7/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0056 - crf_viterbi_accuracy: 0.9978 - accuracy: 0.0181 - val_loss: 0.0774 - val_crf_viterbi_accuracy: 0.9811 - val_accuracy: 0.9818
#  - f1_train: 0.9716 - f1_val: 0.6954
# Epoch 8/20
# 906/906 [==============================] - 2s 2ms/step - loss: 0.0033 - crf_viterbi_accuracy: 0.9983 - accuracy: 0.0181 - val_loss: 0.0630 - val_crf_viterbi_accuracy: 0.9804 - val_accuracy: 0.9810
#  - f1_train: 0.9881 - f1_val: 0.7381
# Epoch 9/20
# 906/906 [==============================] - 2s 2ms/step - loss: -3.1611e-05 - crf_viterbi_accuracy: 0.9990 - accuracy: 0.0181 - val_loss: 0.0839 - val_crf_viterbi_accuracy: 0.9812 - val_accuracy: 0.9820
#  - f1_train: 0.9967 - f1_val: 0.7239
# Epoch 10/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0021 - crf_viterbi_accuracy: 0.9996 - accuracy: 0.0181 - val_loss: 0.1004 - val_crf_viterbi_accuracy: 0.9810 - val_accuracy: 0.9817
#  - f1_train: 0.9881 - f1_val: 0.6989
# Epoch 11/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0033 - crf_viterbi_accuracy: 0.9996 - accuracy: 0.0181 - val_loss: 0.1033 - val_crf_viterbi_accuracy: 0.9784 - val_accuracy: 0.9793
#  - f1_train: 0.9955 - f1_val: 0.6982
# Epoch 12/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0048 - crf_viterbi_accuracy: 0.9997 - accuracy: 0.0181 - val_loss: 0.1028 - val_crf_viterbi_accuracy: 0.9793 - val_accuracy: 0.9801
#  - f1_train: 0.9931 - f1_val: 0.7191
# Epoch 13/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0058 - crf_viterbi_accuracy: 0.9997 - accuracy: 0.0181 - val_loss: 0.1113 - val_crf_viterbi_accuracy: 0.9800 - val_accuracy: 0.9809
#  - f1_train: 0.9975 - f1_val: 0.7078
# Epoch 14/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0071 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.1068 - val_crf_viterbi_accuracy: 0.9795 - val_accuracy: 0.9804
#  - f1_train: 0.9975 - f1_val: 0.7065
# Epoch 15/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0083 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.1103 - val_crf_viterbi_accuracy: 0.9810 - val_accuracy: 0.9821
#  - f1_train: 0.9988 - f1_val: 0.7293
# Epoch 16/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0094 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.1214 - val_crf_viterbi_accuracy: 0.9800 - val_accuracy: 0.9810
#  - f1_train: 0.9982 - f1_val: 0.7164
# Epoch 17/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0103 - crf_viterbi_accuracy: 0.9998 - accuracy: 0.0181 - val_loss: 0.1115 - val_crf_viterbi_accuracy: 0.9799 - val_accuracy: 0.9806
#  - f1_train: 0.9989 - f1_val: 0.7349
# Epoch 18/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0116 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.1148 - val_crf_viterbi_accuracy: 0.9831 - val_accuracy: 0.9835
#  - f1_train: 0.9992 - f1_val: 0.7394
# Epoch 19/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0126 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.1220 - val_crf_viterbi_accuracy: 0.9812 - val_accuracy: 0.9818
#  - f1_train: 0.9994 - f1_val: 0.7217
# Epoch 20/20
# 906/906 [==============================] - 2s 2ms/step - loss: -0.0136 - crf_viterbi_accuracy: 0.9999 - accuracy: 0.0181 - val_loss: 0.1118 - val_crf_viterbi_accuracy: 0.9814 - val_accuracy: 0.9821
#  - f1_train: 0.9989 - f1_val: 0.7365

# %%
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['f1_score_train']
    val_accuracy = history.history['f1_score_val']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation F1 score')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
from tensorflow.keras.models import load_model
from keras.models import load_model

def create_custom_objects():
    instanceHolder = {"instance": None}
    class ClassWrapper(CRF):
        def __init__(self, *args, **kwargs):
            instanceHolder["instance"] = self
            super(ClassWrapper, self).__init__(*args, **kwargs)
    def loss(*args):
        method = getattr(instanceHolder["instance"], "loss_function")
        return method(*args)
    def accuracy(*args):
        method = getattr(instanceHolder["instance"], "accuracy")
        return method(*args)
    return {"ClassWrapper": ClassWrapper ,"CRF": ClassWrapper, "crf_loss": loss, "crf_viterbi_accuracy":accuracy}

def load_keras_model(path):
    model = load_model(path, custom_objects=create_custom_objects())
    return model

model = load_keras_model('/kaggle/working/fasttext_ate_3.h5')

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
print(len(X_test))
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 328
# 328/328 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            B       0.73      0.64      0.68       463
#            I       0.55      0.52      0.54       243
#            O       0.99      0.99      0.99     24878
#
#     accuracy                           0.98     25584
#    macro avg       0.76      0.72      0.74     25584
# weighted avg       0.98      0.98      0.98     25584
