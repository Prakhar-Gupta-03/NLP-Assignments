# %%
import json
import pandas as pd
import numpy as np
import re
import string

data = json.load(open('/kaggle/input/json-data/NER_test.json'))
sentence = []
Tag = []
Words = []
count = 0
for i in data:

    for j in data[i]['labels']:
        sentence.append(str(count))
        Tag.append(j)
    for j in data[i]['text'].split():
        # check if there is any special character in the start or end of the word
        if len(j)>2:
            if j[0] in ['.','!','?',',',';',':' ]:
                j = j[1:]
            if j[-1] in ['.','!','?',',',';',':']:
                j = j[:-1]
        Words.append(j)
    count+=1
c = {"Sentence #":sentence,"Word":Words,"Tag":Tag}
print(len(sentence),len(Words),len(Tag))
# save this as csv file
df = pd.DataFrame(c)
df.to_csv('ner_test.csv',index=False)
data = json.load(open('/kaggle/input/json-data/NER_train.json'))
sentence = []
Tag = []
Words = []
count = 0
for i in data:

    for j in data[i]['labels']:
        sentence.append(str(count))
        Tag.append(j)
    for j in data[i]['text'].split():
        # check if there is any special character in the start or end of the word
        if len(j)>2:
            if j[0] in ['.','!','?',',',';',':' ]:
                j = j[1:]
            if j[-1] in ['.','!','?',',',';',':']:
                j = j[:-1]
        Words.append(j)
    count+=1
c = {"Sentence #":sentence,"Word":Words,"Tag":Tag}
print(len(sentence),len(Words),len(Tag))
# save this as csv file
df = pd.DataFrame(c)
df.to_csv('ner_train.csv',index=False)

data = json.load(open('/kaggle/input/json-data/NER_val.json'))
sentence = []
Tag = []
Words = []
count = 0
for i in data:

    for j in data[i]['labels']:
        sentence.append(str(count))
        Tag.append(j)
    for j in data[i]['text'].split():
        # check if there is any special character in the start or end of the word
        if len(j)>2:
            if j[0] in ['.','!','?',',',';',':' ]:
                j = j[1:]
            if j[-1] in ['.','!','?',',',';',':']:
                j = j[:-1]
        Words.append(j)
    count+=1
c = {"Sentence #":sentence,"Word":Words,"Tag":Tag}
print(len(sentence),len(Words),len(Tag))
# save this as csv file
df = pd.DataFrame(c)
df.to_csv('ner_val.csv',index=False)
# Out:
# 33753 33753 33753
# 269722 269722 269722
# 47517 47517 47517

# %%
# data = pd.read_csv("/kaggle/input/entity-annotated-corpus/ner_dataset.csv", encoding="latin1")

# data = pd.read_csv("/kaggle/input/dsets-t3/train.csv")
# test_data = pd.read_csv("/kaggle/input/dsets-t3/test.csv")
test_data = pd.read_csv("/kaggle/working/ner_test.csv")
data = pd.read_csv("/kaggle/working/ner_train.csv")
val_data = pd.read_csv("/kaggle/working/ner_val.csv")
# print(len(data))
words = []

# %%
# print(data.head())
words = []
count = 0
def remove_punct(word):
    pun = list(".,()-:;?!")
    try:
        for i in pun:
            if i in word:
#                 print(i)
                word = word.replace(i,"")
    except:
        word = word
#     print(word)
    return word       
for i in data['Word']:
    words.append(remove_punct(i))

# %%
print(len(words),len(data))
data['Word'] = words
# Out:
# 269722 269722

# %%
data['Tag'].value_counts()
# Out:
# O                 226739
# I_PRECEDENT         9648
# I_PROVISION         3330
# I_CASE_NUMBER       3106
# I_STATUTE           2740
# B_OTHER_PERSON      2279
# I_ORG               2273
# I_COURT             2164
# B_PROVISION         2042
# I_OTHER_PERSON      1772
# B_DATE              1590
# B_STATUTE           1523
# B_ORG               1229
# B_GPE               1186
# I_DATE              1163
# B_PRECEDENT         1123
# B_COURT             1103
# B_CASE_NUMBER        884
# B_WITNESS            760
# I_WITNESS            634
# B_JUDGE              489
# B_PETITIONER         401
# I_RESPONDENT         365
# I_JUDGE              342
# I_PETITIONER         323
# B_RESPONDENT         274
# I_GPE                240
# Name: Tag, dtype: int64

# %%
# data.head(1)

# %%
class SentenceGetter(object):
    
    def __init__(self, dataset):
        self.n_sent = 1
        self.dataset = dataset
        self.empty = False
        agg_func = lambda s: [(w, t) for w,t in zip(s["Word"].values.tolist(),
                                                        s["Tag"].values.tolist())]
        self.grouped = self.dataset.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None
          
getter = SentenceGetter(data)
sentences = getter.sentences

test_getter = SentenceGetter(test_data)
test_sentences = test_getter.sentences
print(len(test_sentences),len(sentences))

val_getter = SentenceGetter(val_data)
val_sentences = test_getter.sentences
# Out:
# 949 8019

# %%
from math import nan
# temp_data = data+test_data
words = list(set(data["Word"].values))
test_words = list(set(test_data['Word'].values))
words = set(words+test_words)
n_words = len(words)

tags = []
for tag in set(data["Tag"].values):
    if tag is nan or isinstance(tag, float):
        tags.append('unk')
    else:
        tags.append(tag)
n_tags = len(tags)

# %% [markdown]
# ## Prepare the data
# Now we introduce dictionaries of words and tags.

# %%
from future.utils import iteritems


word2idx = {w: i for i, w in enumerate(words)}
idx2word = {i:w for w, i in word2idx.items()}
tag2idx = {t: i for i, t in enumerate(tags)}
idx2tag = {v: k for k, v in iteritems(tag2idx)}

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

maxlen = max([len(s) for s in sentences])

X = [[word2idx[w[0]] for w in s] for s in sentences]
X_train = pad_sequences(maxlen=maxlen, sequences=X, padding="post",value=n_words - 1)

y = [[tag2idx[w[1]] for w in s] for s in sentences]
y = pad_sequences(maxlen=maxlen, sequences=y, padding="post", value=tag2idx["O"])
y_train = [to_categorical(i, num_classes=n_tags) for i in y]
X_test = [[word2idx[w[0]] for w in s] for s in test_sentences]
print(len(X_test))
X_test = pad_sequences(maxlen=maxlen, sequences=X_test, padding="post",value=n_words - 1) 

y_test = [[tag2idx[w[1]] for w in s] for s in test_sentences]
print(len(y_test))
y_test = pad_sequences(maxlen=maxlen, sequences=y_test, padding="post", value=tag2idx["O"])
y_test = [to_categorical(i, num_classes=n_tags) for i in y_test]
print(len(y_test))


X_val = [[word2idx[w[0]] for w in s] for s in val_sentences]
print(len(X_val))
X_val = pad_sequences(maxlen=maxlen, sequences=X_val, padding="post",value=n_words - 1) 

y_val = [[tag2idx[w[1]] for w in s] for s in val_sentences]
print(len(y_val))
y_val = pad_sequences(maxlen=maxlen, sequences=y_val, padding="post", value=tag2idx["O"])
y_val = [to_categorical(i, num_classes=n_tags) for i in y_val]
print(len(y_test))
# Split train and test data
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# X_train = data['Word']
# y_train = data['Tag']

# X_test = test_data['Word']
# y_test = test_data['Tag']

print(len(X_test),len(X_train))
# Out:
# Using TensorFlow backend.
# 949
# 949
# 949
# 949
# 949
# 949
# 949 8019

# %% [markdown]
# ## Setup the CRF-BILSTM

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-3sjvcjxk
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-3sjvcjxk
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.13.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.17.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.3.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (2.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (5.1.2)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101065 sha256=8f7abb664e214d87b8f1289f77bc947aab415cb5c368012ff7a0175dac154a5d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1ejzpgyv/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
# Collecting sklearn_crfsuite
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from sklearn_crfsuite) (1.13.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/5e/c5/ec8156ea62dd45df5ef05510281e8b72795a956914d8c12694c0c08f7373/python_crfsuite-0.9.10-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 5.6MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=2.0 in /opt/conda/lib/python3.6/site-packages (from sklearn_crfsuite) (4.39.0)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.6/site-packages/tabulate-0.8.6-py3.6.egg (from sklearn_crfsuite) (0.8.6)
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.10 sklearn-crfsuite-0.3.6

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF

# %%
print(k.__version__)
# Out:
# 2.3.1

# %% [markdown]
# ## F1 MACRO

# %%
from tensorflow.keras.callbacks import Callback
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite.utils import flatten
from sklearn.metrics import f1_score

def F1_Score(y_test,y_pred):
    y_test = np.argmax(y_test, axis=2)
    # Flatten y_pred if necessary
    if y_pred.ndim == 3:
        y_pred = np.argmax(y_pred, axis=2)
    classes = np.unique(y_test)
    precision = []
    recall = []
    f1 = []
    for c in classes:
        tp = np.sum((y_test == c) & (y_pred == c))
        fp = np.sum((y_test != c) & (y_pred == c))
        fn = np.sum((y_test == c) & (y_pred != c))
        
        precision_c = tp / (tp + fp) if tp + fp > 0 else 0
        recall_c = tp / (tp + fn) if tp + fn > 0 else 0
        f1_c = 2 * (precision_c * recall_c) / (precision_c + recall_c) if precision_c + recall_c > 0 else 0
        
        precision.append(precision_c)
        recall.append(recall_c)
        f1.append(f1_c)

    macro_precision = np.mean(precision)
    macro_recall = np.mean(recall)
    macro_f1 = np.mean(f1)

    return macro_f1

class F1ScoreCallback(Callback):
    def __init__(self, X_train, y_train, X_val, y_val):
        self.X_train = X_train
        self.y_train = y_train
        self.X_val = X_val
        self.y_val = y_val

    def on_epoch_end(self, epoch, logs={}):
        # Predict on training and validation sets
        y_train_pred = np.argmax(self.model.predict(self.X_train), axis=-1)
        y_val_pred = np.argmax(self.model.predict(self.X_val), axis=-1)

        # Calculate F1 scores for training and validation sets
        f1_train = F1_Score(self.y_train, y_train_pred)
        f1_val = F1_Score(self.y_val, y_val_pred)



#         print(f' - F1 Score (train): {f1_train:.4f}')
#         print(f' - F1 Score (val): {f1_val:.4f}')

#         # Log F1 scores to the logs dictionary (for logging with Keras)
        if logs is not None:
            logs['f1_score_train'] = f1_train
            logs['f1_score_val'] = f1_val

        # Print F1 scores
        print(f' - f1_train: {f1_train:.4f} - f1_val: {f1_val:.4f}')
f1_callback = F1ScoreCallback(X_train, np.array(y_train), X_val, np.array(y_val))

# %% [markdown]
# ## GLOVE

# %%
input = Input(shape=(1,))
word_embedding_size = 10

embedding_path = '/kaggle/input/glove6b100dtxt/glove.6B.100d.txt'
embedding_dim = 100
def load_glove_embeddings(embedding_path, embedding_dim, word_index):
    embeddings_index = {}
    with open(embedding_path, encoding='utf-8') as f:
        print(f)
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs

    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
    return embedding_matrix

embedding_matrix = load_glove_embeddings(embedding_path, embedding_dim, word2idx)
# Out:
# <_io.TextIOWrapper name='/kaggle/input/glove6b100dtxt/glove.6B.100d.txt' mode='r' encoding='utf-8'>

# %%
from keras.models import Model, Input,Sequential
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF
# m = 78
m = 76
input = Input(shape=(m,))
word_embedding_size = 100
model = Sequential()
model.add(Embedding(input_dim=n_words+1, output_dim=100, input_length=m, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.01)))

model.add(TimeDistributed(Dense(n_tags)))
# model.add(Activation('relu'))
crf = CRF(n_tags)
model.add(crf)
model2 = model

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 76, 100)           2746600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 76, 100)           0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 76, 200)           160800
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 76, 27)            5427
# _________________________________________________________________
# crf_3 (CRF)                  (None, 76, 27)            1539
# =================================================================
# Total params: 2,914,366
# Trainable params: 2,914,366
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.02, beta_1=0.5, beta_2=0.5)

# # Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])


# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=128, epochs=20, validation_data = (X_val,np.array(y_val)), verbose=1,callbacks=[f1_callback])

import joblib

# Assuming `model` is your Keras model
# Save the model
# joblib.dump(model, "glove_ner_3.pkl")
weights = model.get_weights()
joblib.dump(weights, 'glove_ner_3_weights.pkl')
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 8019 samples, validate on 949 samples
# Epoch 1/20
# 8019/8019 [==============================] - 16s 2ms/step - loss: 0.1924 - crf_viterbi_accuracy: 0.9663 - accuracy: 4.4959e-04 - val_loss: 0.0634 - val_crf_viterbi_accuracy: 0.9679 - val_accuracy: 0.9678
#  - f1_train: 0.8655 - f1_val: 0.5525
# Epoch 2/20
# 8019/8019 [==============================] - 13s 2ms/step - loss: -0.0166 - crf_viterbi_accuracy: 0.9914 - accuracy: 4.4959e-04 - val_loss: 0.0146 - val_crf_viterbi_accuracy: 0.9740 - val_accuracy: 0.9740
#  - f1_train: 0.9372 - f1_val: 0.6101
# Epoch 3/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.0409 - crf_viterbi_accuracy: 0.9943 - accuracy: 4.4959e-04 - val_loss: 0.0103 - val_crf_viterbi_accuracy: 0.9701 - val_accuracy: 0.9697
#  - f1_train: 0.9607 - f1_val: 0.6369
# Epoch 4/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.0605 - crf_viterbi_accuracy: 0.9956 - accuracy: 4.4959e-04 - val_loss: -0.0146 - val_crf_viterbi_accuracy: 0.9722 - val_accuracy: 0.9721
#  - f1_train: 0.9750 - f1_val: 0.6308
# Epoch 5/20
# 8019/8019 [==============================] - 13s 2ms/step - loss: -0.0790 - crf_viterbi_accuracy: 0.9966 - accuracy: 4.4959e-04 - val_loss: -0.0248 - val_crf_viterbi_accuracy: 0.9706 - val_accuracy: 0.9703
#  - f1_train: 0.9724 - f1_val: 0.5968
# Epoch 6/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.0966 - crf_viterbi_accuracy: 0.9973 - accuracy: 4.4959e-04 - val_loss: -0.0394 - val_crf_viterbi_accuracy: 0.9682 - val_accuracy: 0.9683
#  - f1_train: 0.9792 - f1_val: 0.6150
# Epoch 7/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.1139 - crf_viterbi_accuracy: 0.9975 - accuracy: 4.4959e-04 - val_loss: -0.0498 - val_crf_viterbi_accuracy: 0.9680 - val_accuracy: 0.9680
#  - f1_train: 0.9809 - f1_val: 0.5895
# Epoch 8/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.1310 - crf_viterbi_accuracy: 0.9977 - accuracy: 4.4959e-04 - val_loss: -0.0601 - val_crf_viterbi_accuracy: 0.9687 - val_accuracy: 0.9681
#  - f1_train: 0.9881 - f1_val: 0.6273
# Epoch 9/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.1478 - crf_viterbi_accuracy: 0.9979 - accuracy: 4.4959e-04 - val_loss: -0.0774 - val_crf_viterbi_accuracy: 0.9705 - val_accuracy: 0.9703
#  - f1_train: 0.9906 - f1_val: 0.6238
# Epoch 10/20
# 8019/8019 [==============================] - 13s 2ms/step - loss: -0.1646 - crf_viterbi_accuracy: 0.9981 - accuracy: 4.4959e-04 - val_loss: -0.0817 - val_crf_viterbi_accuracy: 0.9676 - val_accuracy: 0.9672
#  - f1_train: 0.9901 - f1_val: 0.6291
# Epoch 11/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.1811 - crf_viterbi_accuracy: 0.9981 - accuracy: 4.4959e-04 - val_loss: -0.1037 - val_crf_viterbi_accuracy: 0.9686 - val_accuracy: 0.9684
#  - f1_train: 0.9923 - f1_val: 0.6158
# Epoch 12/20
# 8019/8019 [==============================] - 13s 2ms/step - loss: -0.1981 - crf_viterbi_accuracy: 0.9982 - accuracy: 4.4959e-04 - val_loss: -0.1138 - val_crf_viterbi_accuracy: 0.9691 - val_accuracy: 0.9689
#  - f1_train: 0.9904 - f1_val: 0.6242
# Epoch 13/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.2147 - crf_viterbi_accuracy: 0.9982 - accuracy: 4.4959e-04 - val_loss: -0.1158 - val_crf_viterbi_accuracy: 0.9650 - val_accuracy: 0.9648
#  - f1_train: 0.9916 - f1_val: 0.6185
# Epoch 14/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.2313 - crf_viterbi_accuracy: 0.9984 - accuracy: 4.4959e-04 - val_loss: -0.1434 - val_crf_viterbi_accuracy: 0.9675 - val_accuracy: 0.9670
#  - f1_train: 0.9910 - f1_val: 0.5888
# Epoch 15/20
# 8019/8019 [==============================] - 13s 2ms/step - loss: -0.2479 - crf_viterbi_accuracy: 0.9983 - accuracy: 4.4959e-04 - val_loss: -0.1484 - val_crf_viterbi_accuracy: 0.9685 - val_accuracy: 0.9685
#  - f1_train: 0.9956 - f1_val: 0.6265
# Epoch 16/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.2645 - crf_viterbi_accuracy: 0.9984 - accuracy: 4.4959e-04 - val_loss: -0.1452 - val_crf_viterbi_accuracy: 0.9642 - val_accuracy: 0.9640
#  - f1_train: 0.9949 - f1_val: 0.5733
# Epoch 17/20
# 8019/8019 [==============================] - 13s 2ms/step - loss: -0.2810 - crf_viterbi_accuracy: 0.9984 - accuracy: 4.4959e-04 - val_loss: -0.1759 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9681
#  - f1_train: 0.9936 - f1_val: 0.6013
# Epoch 18/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.2978 - crf_viterbi_accuracy: 0.9985 - accuracy: 4.4959e-04 - val_loss: -0.1853 - val_crf_viterbi_accuracy: 0.9673 - val_accuracy: 0.9669
#  - f1_train: 0.9912 - f1_val: 0.6302
# Epoch 19/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.3144 - crf_viterbi_accuracy: 0.9987 - accuracy: 4.4959e-04 - val_loss: -0.2007 - val_crf_viterbi_accuracy: 0.9656 - val_accuracy: 0.9651
#  - f1_train: 0.9944 - f1_val: 0.6053
# Epoch 20/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: -0.3309 - crf_viterbi_accuracy: 0.9985 - accuracy: 4.4959e-04 - val_loss: -0.2096 - val_crf_viterbi_accuracy: 0.9674 - val_accuracy: 0.9671
#  - f1_train: 0.9922 - f1_val: 0.6093
# ['glove_ner_3_weights.pkl']

# %%
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['f1_score_train']
    val_accuracy = history.history['f1_score_val']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation F1 score')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
from tensorflow.keras.models import load_model
weights = joblib.load('/kaggle/working/glove_ner_3_weights.pkl')
model2.set_weights(weights)
model = model2

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
print(len(X_test))
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
# 949
# 949/949 [==============================] - 1s 1ms/step
#                 precision    recall  f1-score   support
#
#  B_CASE_NUMBER       0.60      0.55      0.58       121
#        B_COURT       0.90      0.86      0.88       178
#         B_DATE       0.91      0.74      0.82       222
#          B_GPE       0.37      0.60      0.45       183
#        B_JUDGE       0.31      0.62      0.42         8
#          B_ORG       0.44      0.47      0.45       159
# B_OTHER_PERSON       0.57      0.62      0.59       276
#   B_PETITIONER       0.29      0.44      0.35         9
#    B_PRECEDENT       0.69      0.59      0.64       177
#    B_PROVISION       0.87      0.91      0.89       258
#   B_RESPONDENT       0.07      0.40      0.12         5
#      B_STATUTE       0.88      0.84      0.86       222
#      B_WITNESS       0.50      0.21      0.29        58
#  I_CASE_NUMBER       0.63      0.81      0.71       344
#        I_COURT       0.88      0.81      0.84       326
#         I_DATE       0.78      0.92      0.85       102
#          I_GPE       0.22      0.45      0.29        47
#        I_JUDGE       0.46      0.86      0.60         7
#          I_ORG       0.41      0.51      0.46       310
# I_OTHER_PERSON       0.51      0.70      0.59       195
#   I_PETITIONER       0.54      0.64      0.58        11
#    I_PRECEDENT       0.93      0.75      0.83      1793
#    I_PROVISION       0.85      0.92      0.88       439
#   I_RESPONDENT       0.15      0.67      0.24         9
#      I_STATUTE       0.85      0.89      0.87       383
#      I_WITNESS       0.52      0.30      0.38        54
#              O       0.99      0.99      0.99     66228
#
#       accuracy                           0.97     72124
#      macro avg       0.60      0.67      0.61     72124
#   weighted avg       0.97      0.97      0.97     72124

# %%
# ! pip install seqeval

# %% [markdown]
# ## WORD2VEC

# %%
from gensim.models import KeyedVectors
from tqdm import tqdm
input = Input(shape=(76,))
word_embedding_size = 150
embedding_dim = 300
print("here")
word2vec_path = "/kaggle/input/googlenewsvectorsnegative300/GoogleNews-vectors-negative300.bin"  # Replace this with the path to your Word2Vec model

def load_word2vec_embeddings(word2vec_path, embedding_dim, word_index):
    word2vec_model = KeyedVectors.load_word2vec_format(word2vec_path, binary=True)
    print("loading done")
    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
    for word, i in tqdm(word_index.items()):
        if word in word2vec_model:
            embedding_matrix[i] = word2vec_model[word]

    return embedding_matrix

embedding_matrix = load_word2vec_embeddings(word2vec_path, embedding_dim, word2idx)
# Out:
# here
# 100%|██████████| 27465/27465 [00:00<00:00, 171927.21it/s]
# loading done

# %%
# m = 78
m = 76
input = Input(shape=(m,))
word_embedding_size = 100
model = Sequential()
model.add(Embedding(input_dim=n_words+1, output_dim=300, input_length=m, weights=[embedding_matrix]))
model.add(Dropout(0.4))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.01)))

model.add(TimeDistributed(Dense(n_tags)))
# model.add(Activation('relu'))
crf_layer = CRF(n_tags)
model.add(crf_layer)

model2 = model
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.005)

# # Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])


# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=128, epochs=20, validation_data = (X_val,np.array(y_val)), verbose=1,callbacks=[f1_callback])

import joblib

# Assuming `model` is your Keras model
# Save the model
weights = model.get_weights()
joblib.dump(weights, 'word2vec_ner_3_weights.pkl')
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 8019 samples, validate on 949 samples
# Epoch 1/20
# 8019/8019 [==============================] - 14s 2ms/step - loss: 0.4500 - crf_viterbi_accuracy: 0.9049 - accuracy: 4.4959e-04 - val_loss: 0.1883 - val_crf_viterbi_accuracy: 0.9498 - val_accuracy: 0.9499
#  - f1_train: 0.2729 - f1_val: 0.2562
# Epoch 2/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: 0.1081 - crf_viterbi_accuracy: 0.9681 - accuracy: 4.4959e-04 - val_loss: 0.0993 - val_crf_viterbi_accuracy: 0.9657 - val_accuracy: 0.9658
#  - f1_train: 0.5484 - f1_val: 0.4427
# Epoch 3/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: 0.0416 - crf_viterbi_accuracy: 0.9831 - accuracy: 4.4959e-04 - val_loss: 0.0730 - val_crf_viterbi_accuracy: 0.9704 - val_accuracy: 0.9703
#  - f1_train: 0.7367 - f1_val: 0.5135
# Epoch 4/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: 0.0131 - crf_viterbi_accuracy: 0.9901 - accuracy: 4.4959e-04 - val_loss: 0.0750 - val_crf_viterbi_accuracy: 0.9693 - val_accuracy: 0.9694
#  - f1_train: 0.8560 - f1_val: 0.5402
# Epoch 5/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: -0.0026 - crf_viterbi_accuracy: 0.9939 - accuracy: 4.4959e-04 - val_loss: 0.0639 - val_crf_viterbi_accuracy: 0.9720 - val_accuracy: 0.9719
#  - f1_train: 0.9410 - f1_val: 0.5694
# Epoch 6/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0127 - crf_viterbi_accuracy: 0.9958 - accuracy: 4.4959e-04 - val_loss: 0.0663 - val_crf_viterbi_accuracy: 0.9719 - val_accuracy: 0.9718
#  - f1_train: 0.9658 - f1_val: 0.5595
# Epoch 7/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0207 - crf_viterbi_accuracy: 0.9971 - accuracy: 4.4959e-04 - val_loss: 0.0648 - val_crf_viterbi_accuracy: 0.9707 - val_accuracy: 0.9705
#  - f1_train: 0.9786 - f1_val: 0.5563
# Epoch 8/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0269 - crf_viterbi_accuracy: 0.9977 - accuracy: 4.4959e-04 - val_loss: 0.0731 - val_crf_viterbi_accuracy: 0.9698 - val_accuracy: 0.9698
#  - f1_train: 0.9859 - f1_val: 0.5464
# Epoch 9/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: -0.0327 - crf_viterbi_accuracy: 0.9983 - accuracy: 4.4959e-04 - val_loss: 0.0695 - val_crf_viterbi_accuracy: 0.9691 - val_accuracy: 0.9691
#  - f1_train: 0.9876 - f1_val: 0.5416
# Epoch 10/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: -0.0378 - crf_viterbi_accuracy: 0.9986 - accuracy: 4.4959e-04 - val_loss: 0.0696 - val_crf_viterbi_accuracy: 0.9700 - val_accuracy: 0.9698
#  - f1_train: 0.9934 - f1_val: 0.5639
# Epoch 11/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0430 - crf_viterbi_accuracy: 0.9990 - accuracy: 4.4959e-04 - val_loss: 0.0800 - val_crf_viterbi_accuracy: 0.9689 - val_accuracy: 0.9690
#  - f1_train: 0.9945 - f1_val: 0.5633
# Epoch 12/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: -0.0477 - crf_viterbi_accuracy: 0.9991 - accuracy: 4.4959e-04 - val_loss: 0.0698 - val_crf_viterbi_accuracy: 0.9701 - val_accuracy: 0.9703
#  - f1_train: 0.9961 - f1_val: 0.5678
# Epoch 13/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: -0.0524 - crf_viterbi_accuracy: 0.9993 - accuracy: 4.4959e-04 - val_loss: 0.0748 - val_crf_viterbi_accuracy: 0.9697 - val_accuracy: 0.9699
#  - f1_train: 0.9977 - f1_val: 0.5505
# Epoch 14/20
# 8019/8019 [==============================] - 12s 1ms/step - loss: -0.0569 - crf_viterbi_accuracy: 0.9995 - accuracy: 4.4959e-04 - val_loss: 0.0680 - val_crf_viterbi_accuracy: 0.9701 - val_accuracy: 0.9700
#  - f1_train: 0.9978 - f1_val: 0.5553
# Epoch 15/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0613 - crf_viterbi_accuracy: 0.9995 - accuracy: 4.4959e-04 - val_loss: 0.0667 - val_crf_viterbi_accuracy: 0.9694 - val_accuracy: 0.9694
#  - f1_train: 0.9988 - f1_val: 0.5752
# Epoch 16/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0657 - crf_viterbi_accuracy: 0.9996 - accuracy: 4.4959e-04 - val_loss: 0.0786 - val_crf_viterbi_accuracy: 0.9685 - val_accuracy: 0.9686
#  - f1_train: 0.9981 - f1_val: 0.5531
# Epoch 17/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0700 - crf_viterbi_accuracy: 0.9996 - accuracy: 4.4959e-04 - val_loss: 0.0702 - val_crf_viterbi_accuracy: 0.9693 - val_accuracy: 0.9693
#  - f1_train: 0.9990 - f1_val: 0.5577
# Epoch 18/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0743 - crf_viterbi_accuracy: 0.9997 - accuracy: 4.4959e-04 - val_loss: 0.0734 - val_crf_viterbi_accuracy: 0.9701 - val_accuracy: 0.9702
#  - f1_train: 0.9988 - f1_val: 0.5812
# Epoch 19/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0786 - crf_viterbi_accuracy: 0.9997 - accuracy: 4.4959e-04 - val_loss: 0.0636 - val_crf_viterbi_accuracy: 0.9700 - val_accuracy: 0.9699
#  - f1_train: 0.9994 - f1_val: 0.5740
# Epoch 20/20
# 8019/8019 [==============================] - 12s 2ms/step - loss: -0.0829 - crf_viterbi_accuracy: 0.9998 - accuracy: 4.4959e-04 - val_loss: 0.0624 - val_crf_viterbi_accuracy: 0.9691 - val_accuracy: 0.9691
#  - f1_train: 0.9993 - f1_val: 0.5545
# ['word2vec_ner_3_weights.pkl']

# %%
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['f1_score_train']
    val_accuracy = history.history['f1_score_val']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation F1 score')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
from tensorflow.keras.models import load_model
weights = joblib.load('/kaggle/working/word2vec_ner_3_weights.pkl')
model2.set_weights(weights)
model = model2
def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
print(len(X_test))
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
# 949
# 949/949 [==============================] - 1s 1ms/step
#                 precision    recall  f1-score   support
#
#  B_CASE_NUMBER       0.77      0.41      0.54       121
#        B_COURT       0.92      0.83      0.87       178
#         B_DATE       0.75      0.68      0.72       222
#          B_GPE       0.59      0.45      0.51       183
#        B_JUDGE       0.15      0.25      0.19         8
#          B_ORG       0.70      0.42      0.52       159
# B_OTHER_PERSON       0.74      0.64      0.69       276
#   B_PETITIONER       0.22      0.22      0.22         9
#    B_PRECEDENT       0.75      0.62      0.68       177
#    B_PROVISION       0.91      0.87      0.89       258
#   B_RESPONDENT       0.00      0.00      0.00         5
#      B_STATUTE       0.88      0.76      0.81       222
#      B_WITNESS       0.42      0.22      0.29        58
#  I_CASE_NUMBER       0.78      0.67      0.72       344
#        I_COURT       0.84      0.82      0.83       326
#         I_DATE       0.80      0.89      0.84       102
#          I_GPE       0.38      0.43      0.40        47
#        I_JUDGE       0.10      0.14      0.12         7
#          I_ORG       0.61      0.42      0.50       310
# I_OTHER_PERSON       0.66      0.72      0.69       195
#   I_PETITIONER       0.20      0.09      0.13        11
#    I_PRECEDENT       0.93      0.79      0.85      1793
#    I_PROVISION       0.88      0.83      0.85       439
#   I_RESPONDENT       0.10      0.22      0.14         9
#      I_STATUTE       0.84      0.80      0.82       383
#      I_WITNESS       0.38      0.20      0.27        54
#              O       0.98      0.99      0.99     66228
#
#       accuracy                           0.97     72124
#      macro avg       0.60      0.53      0.56     72124
#   weighted avg       0.97      0.97      0.97     72124

# %% [markdown]
# ## Fast Text

# %%
from gensim.models import KeyedVectors
from tqdm import tqdm

word_embedding_size = 150
embedding_dim = 300
# print("here")
# fasttext_path = "/kaggle/input/fasttext-crawl-300d-2m/crawl-300d-2M.vec"  # Replace this with the path to your FastText model

# def load_fasttext_embeddings(fasttext_path, embedding_dim, word_index):
#     fasttext_model = KeyedVectors.load_word2vec_format(fasttext_path, binary=False, encoding='utf-8')
#     print("Loading FastText embeddings...")
#     embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
#     for word, i in tqdm(word_index.items()):
#         if word in fasttext_model:
#             embedding_matrix[i] = fasttext_model[word]

#     return embedding_matrix

# embedding_matrix = load_fasttext_embeddings(fasttext_path, embedding_dim, word2idx)

# %%
import torch
from torchtext.vocab import FastText

# Load FastText embeddings
fasttext = FastText(language='en')

# Get the embedding dimension
embedding_dim = fasttext.dim

# Initialize the embedding matrix
embedding_matrix = torch.zeros((len(word2idx) + 1, embedding_dim))

# Populate the embedding matrix
for word, idx in tqdm(word2idx.items()):
    if word in fasttext.stoi:
        embedding_matrix[idx] = fasttext[word]
# Out:
# .vector_cache/wiki.en.vec: 6.60GB [00:29, 221MB/s]
# 100%|█████████▉| 2518843/2519370 [05:23<00:00, 7831.95it/s]
#   0%|          | 0/27465 [00:00<?, ?it/s]
# 100%|██████████| 27465/27465 [00:00<00:00, 172875.14it/s]

# %%
# m = 78
m = 76
input = Input(shape=(m,))
word_embedding_size = 100
model = Sequential()
model.add(Embedding(input_dim=n_words+1, output_dim=300, input_length=m, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.01)))

model.add(TimeDistributed(Dense(n_tags)))
# model.add(Activation('relu'))
crf_layer = CRF(n_tags)
model.add(crf_layer)
model2 = model

from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.05, beta_1=0.2, beta_2=0.1)

# # Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])


# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=256, epochs=20, validation_data = (X_val,np.array(y_val)), verbose=1,callbacks=[f1_callback])

import joblib

# Assuming `model` is your Keras model
# Save the model
weights = model.get_weights()
joblib.dump(weights, 'fasttext_ner_3_weights.pkl')
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 8019 samples, validate on 949 samples
# Epoch 1/20
# 8019/8019 [==============================] - 8s 1ms/step - loss: 0.6757 - crf_viterbi_accuracy: 0.8690 - accuracy: 4.4959e-04 - val_loss: 0.0870 - val_crf_viterbi_accuracy: 0.9586 - val_accuracy: 0.9584
#  - f1_train: 0.5169 - f1_val: 0.4242
# Epoch 2/20
# 8019/8019 [==============================] - 6s 767us/step - loss: 0.0238 - crf_viterbi_accuracy: 0.9765 - accuracy: 4.4959e-04 - val_loss: 0.0279 - val_crf_viterbi_accuracy: 0.9639 - val_accuracy: 0.9636
#  - f1_train: 0.7814 - f1_val: 0.5384
# Epoch 3/20
# 8019/8019 [==============================] - 6s 793us/step - loss: -0.0237 - crf_viterbi_accuracy: 0.9859 - accuracy: 4.4959e-04 - val_loss: 0.0108 - val_crf_viterbi_accuracy: 0.9625 - val_accuracy: 0.9621
#  - f1_train: 0.8735 - f1_val: 0.5550
# Epoch 4/20
# 8019/8019 [==============================] - 6s 770us/step - loss: -0.0525 - crf_viterbi_accuracy: 0.9893 - accuracy: 4.4959e-04 - val_loss: 4.7943e-04 - val_crf_viterbi_accuracy: 0.9568 - val_accuracy: 0.9564
#  - f1_train: 0.9007 - f1_val: 0.5309
# Epoch 5/20
# 8019/8019 [==============================] - 6s 770us/step - loss: -0.0768 - crf_viterbi_accuracy: 0.9909 - accuracy: 4.4959e-04 - val_loss: -0.0168 - val_crf_viterbi_accuracy: 0.9610 - val_accuracy: 0.9609
#  - f1_train: 0.9056 - f1_val: 0.5165
# Epoch 6/20
# 8019/8019 [==============================] - 6s 768us/step - loss: -0.0992 - crf_viterbi_accuracy: 0.9917 - accuracy: 4.4959e-04 - val_loss: -0.0183 - val_crf_viterbi_accuracy: 0.9525 - val_accuracy: 0.9524
#  - f1_train: 0.9143 - f1_val: 0.4932
# Epoch 7/20
# 8019/8019 [==============================] - 6s 781us/step - loss: -0.1207 - crf_viterbi_accuracy: 0.9920 - accuracy: 4.4959e-04 - val_loss: -0.0432 - val_crf_viterbi_accuracy: 0.9587 - val_accuracy: 0.9585
#  - f1_train: 0.9130 - f1_val: 0.5115
# Epoch 8/20
# 8019/8019 [==============================] - 6s 766us/step - loss: -0.1429 - crf_viterbi_accuracy: 0.9925 - accuracy: 4.4959e-04 - val_loss: -0.0483 - val_crf_viterbi_accuracy: 0.9553 - val_accuracy: 0.9550
#  - f1_train: 0.9225 - f1_val: 0.5019
# Epoch 9/20
# 8019/8019 [==============================] - 6s 772us/step - loss: -0.1631 - crf_viterbi_accuracy: 0.9925 - accuracy: 4.4959e-04 - val_loss: -0.0741 - val_crf_viterbi_accuracy: 0.9520 - val_accuracy: 0.9518
#  - f1_train: 0.9136 - f1_val: 0.4931
# Epoch 10/20
# 8019/8019 [==============================] - 6s 810us/step - loss: -0.1846 - crf_viterbi_accuracy: 0.9925 - accuracy: 4.4959e-04 - val_loss: -0.0795 - val_crf_viterbi_accuracy: 0.9596 - val_accuracy: 0.9594
#  - f1_train: 0.9242 - f1_val: 0.5297
# Epoch 11/20
# 8019/8019 [==============================] - 6s 777us/step - loss: -0.2057 - crf_viterbi_accuracy: 0.9926 - accuracy: 4.4959e-04 - val_loss: -0.1157 - val_crf_viterbi_accuracy: 0.9602 - val_accuracy: 0.9599
#  - f1_train: 0.9439 - f1_val: 0.5282
# Epoch 12/20
# 8019/8019 [==============================] - 7s 813us/step - loss: -0.2271 - crf_viterbi_accuracy: 0.9931 - accuracy: 4.4959e-04 - val_loss: -0.1201 - val_crf_viterbi_accuracy: 0.9522 - val_accuracy: 0.9519
#  - f1_train: 0.9058 - f1_val: 0.4849
# Epoch 13/20
# 8019/8019 [==============================] - 7s 813us/step - loss: -0.2477 - crf_viterbi_accuracy: 0.9928 - accuracy: 4.4959e-04 - val_loss: -0.1459 - val_crf_viterbi_accuracy: 0.9538 - val_accuracy: 0.9538
#  - f1_train: 0.9296 - f1_val: 0.5089
# Epoch 14/20
# 8019/8019 [==============================] - 6s 793us/step - loss: -0.2689 - crf_viterbi_accuracy: 0.9927 - accuracy: 4.4959e-04 - val_loss: -0.1729 - val_crf_viterbi_accuracy: 0.9594 - val_accuracy: 0.9591
#  - f1_train: 0.9467 - f1_val: 0.5282
# Epoch 15/20
# 8019/8019 [==============================] - 6s 790us/step - loss: -0.2902 - crf_viterbi_accuracy: 0.9929 - accuracy: 4.4959e-04 - val_loss: -0.1687 - val_crf_viterbi_accuracy: 0.9532 - val_accuracy: 0.9529
#  - f1_train: 0.9399 - f1_val: 0.4869
# Epoch 16/20
# 8019/8019 [==============================] - 6s 792us/step - loss: -0.3102 - crf_viterbi_accuracy: 0.9924 - accuracy: 4.4959e-04 - val_loss: -0.2148 - val_crf_viterbi_accuracy: 0.9578 - val_accuracy: 0.9576
#  - f1_train: 0.9374 - f1_val: 0.5070
# Epoch 17/20
# 8019/8019 [==============================] - 7s 823us/step - loss: -0.3319 - crf_viterbi_accuracy: 0.9929 - accuracy: 4.4959e-04 - val_loss: -0.2253 - val_crf_viterbi_accuracy: 0.9555 - val_accuracy: 0.9551
#  - f1_train: 0.9461 - f1_val: 0.5000
# Epoch 18/20
# 8019/8019 [==============================] - 6s 781us/step - loss: -0.3522 - crf_viterbi_accuracy: 0.9930 - accuracy: 4.4959e-04 - val_loss: -0.2403 - val_crf_viterbi_accuracy: 0.9572 - val_accuracy: 0.9568
#  - f1_train: 0.9312 - f1_val: 0.4900
# Epoch 19/20
# 8019/8019 [==============================] - 6s 787us/step - loss: -0.3736 - crf_viterbi_accuracy: 0.9931 - accuracy: 4.4959e-04 - val_loss: -0.2563 - val_crf_viterbi_accuracy: 0.9550 - val_accuracy: 0.9546
#  - f1_train: 0.9328 - f1_val: 0.4871
# Epoch 20/20
# 8019/8019 [==============================] - 6s 772us/step - loss: -0.3941 - crf_viterbi_accuracy: 0.9927 - accuracy: 4.4959e-04 - val_loss: -0.2734 - val_crf_viterbi_accuracy: 0.9550 - val_accuracy: 0.9546
#  - f1_train: 0.9362 - f1_val: 0.5001
# ['fasttext_ner_3_weights.pkl']

# %%
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['f1_score_train']
    val_accuracy = history.history['f1_score_val']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation F1 score')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
from tensorflow.keras.models import load_model
weights = joblib.load('/kaggle/working/fasttext_ner_3_weights.pkl')
model2.set_weights(weights)
model = model2
def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
print(len(X_test))
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
# 949
# 949/949 [==============================] - 1s 1ms/step
#                 precision    recall  f1-score   support
#
#  B_CASE_NUMBER       0.34      0.55      0.42       121
#        B_COURT       0.81      0.86      0.83       178
#         B_DATE       0.82      0.84      0.83       222
#          B_GPE       0.47      0.25      0.33       183
#        B_JUDGE       0.10      0.50      0.17         8
#          B_ORG       0.36      0.53      0.43       159
# B_OTHER_PERSON       0.38      0.58      0.46       276
#   B_PETITIONER       0.11      0.56      0.18         9
#    B_PRECEDENT       0.73      0.53      0.61       177
#    B_PROVISION       0.90      0.83      0.86       258
#   B_RESPONDENT       0.00      0.00      0.00         5
#      B_STATUTE       0.88      0.83      0.86       222
#      B_WITNESS       0.16      0.24      0.19        58
#  I_CASE_NUMBER       0.39      0.83      0.53       344
#        I_COURT       0.59      0.85      0.70       326
#         I_DATE       0.64      0.86      0.74       102
#          I_GPE       0.36      0.09      0.14        47
#        I_JUDGE       0.11      0.43      0.18         7
#          I_ORG       0.30      0.62      0.40       310
# I_OTHER_PERSON       0.36      0.69      0.47       195
#   I_PETITIONER       0.29      0.36      0.32        11
#    I_PRECEDENT       0.87      0.77      0.82      1793
#    I_PROVISION       0.84      0.82      0.83       439
#   I_RESPONDENT       0.12      0.44      0.19         9
#      I_STATUTE       0.78      0.91      0.84       383
#      I_WITNESS       0.15      0.31      0.21        54
#              O       0.99      0.97      0.98     66228
#
#       accuracy                           0.95     72124
#      macro avg       0.48      0.59      0.50     72124
#   weighted avg       0.97      0.95      0.96     72124
