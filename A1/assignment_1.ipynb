# %% [markdown]
# ## Question 1

# %%
from collections import Counter, defaultdict
class BPE:
    def __init__(self, corpus, merge_size):
        self.corpus = corpus
        self.merge_size = merge_size
        self.word_freqs = defaultdict(int)
        self.splits = {}
        self.merges = {}


    def learn_vocabulary(self):
        # Compute the frequencies of each word in the corpus
        for text in self.corpus:
            words = text.split(" ")
            for word in words:
                self.word_freqs[word] += 1

        # Compute the base vocabulary of all characters in the corpus
        alphabet = []
        for word in self.word_freqs.keys():
            for letter in word:
                if letter not in alphabet:
                    alphabet.append(letter)
        alphabet.sort()

        # Add the special token </w> at the beginning of the vocabulary
        vocab = ["</w>"] + alphabet.copy()

        # Split each word into individual characters before training
        self.splits = {word: [c for c in word] for word in self.word_freqs.keys()}

        # Merge the most frequent pair iteratively until the vocabulary size is reached
        while len(self.merges) < self.merge_size:
            print(len(self.merges),self.merge_size)
            # Compute the frequency of each pair
            pair_freqs = self.compute_pair_freqs()

            # Find the most frequent pair
            best_pair = max(pair_freqs, key=pair_freqs.get)

            # Merge the most frequent pair
            self.splits = self.merge_pair(*best_pair)
            self.merges[best_pair] = best_pair[0] + best_pair[1]
            vocab.append(best_pair[0] + best_pair[1])

        with open('token.txt', 'w') as f:
            for item in vocab:
                f.write(item + '\n')
        with open("merge_rules.txt", 'w') as f:
            print(len(self.merges))
            for item in self.merges:
                f.write(item[0] + ',' + item[1] + ' = ' + self.merges[item] + '\n')
        return self.merges

    def compute_pair_freqs(self):
        pair_freqs = defaultdict(int)
        for word, freq in self.word_freqs.items():
            split = self.splits[word]
            if len(split) == 1:
                continue
            for i in range(len(split) - 1):
                pair = (split[i], split[i + 1])
                pair_freqs[pair] += freq
        # print(pair_freqs)
        return pair_freqs


    def merge_pair(self, a, b):
        for word in self.word_freqs:
            split = self.splits[word]
            if len(split) == 1:
                continue
            i = 0
            while i < len(split) - 1:
                if split[i] == a and split[i + 1] == b:
                    split = split[:i] + [a + b] + split[i + 2 :]
                else:
                    i += 1
            self.splits[word] = split
        return self.splits


    def tokenize(self, text):
        pre_tokenized_text = text.split(" ")
        splits_text = [[l for l in word] for word in pre_tokenized_text]

        for pair, merge in self.merges.items():
            for idx, split in enumerate(splits_text):
                i = 0
                while i < len(split) - 1:
                    if split[i] == pair[0] and split[i + 1] == pair[1]:
                        split = split[:i] + [merge] + split[i + 2 :]
                    else:
                        i += 1
                splits_text[idx] = split
        result = sum(splits_text, [])
        with open('tokenized.txt', 'w') as f:
            for item in result:
                f.write(item + '\n')
        return result

# %%
with open('trail.txt', encoding="utf8") as f:
    corpus = f.readlines()

# set the hyperparameter of vocabulary size
merge_size = 80

# create a BPE tokenizer object
bpe = BPE(corpus=corpus, merge_size=merge_size)

bpe.learn_vocabulary()

text_to_Test = '''i stand here i feel empty a class post count link href http mooshilu
i literally just text tychelle to see if she wants to hang out because reading what i just wrote about my nonexistent social life made me feel so pathetic
i really feel regretful when hearing that shinae got married to another man oh it s really sad i really hope that alex and shinae can be a couple in real life they re perfect for each other
i believed it was true love and feel devastated i wanted to settle down and have the whole marriage and kids thing with him
i feel unimportant so inadequate
i feel very low already'''
bpe.tokenize(text_to_Test)
# Out:
# 0 80
# defaultdict(<class 'int'>, {('T', 'e'): 2, ('e', 's'): 5, ('s', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'p'): 2, ('p', 'l'): 4, ('l', 'e'): 3, ('N', 'a'): 1, ('a', 't'): 3, ('t', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 2, ('a', 'l'): 2, ('l', 'a'): 3, ('a', 'n'): 5, ('n', 'g'): 6, ('g', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 3, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'e'): 1, ('s', 's'): 1, ('s', 'i'): 1, ('i', 'n'): 5, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'e'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'p'): 1, ('l', 'i'): 2, ('i', 'c'): 1, ('c', 'a'): 1, ('t', 'i'): 2, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'i'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('n', 'd'): 2, ('d', 'l'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('o', 'f'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'a'): 1, ('t', 'a'): 1})
# 1 80
# defaultdict(<class 'int'>, {('T', 'e'): 2, ('e', 's'): 5, ('s', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'p'): 2, ('p', 'l'): 4, ('l', 'e'): 3, ('N', 'a'): 1, ('a', 't'): 3, ('t', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 2, ('a', 'l'): 2, ('l', 'a'): 3, ('a', 'ng'): 3, ('ng', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 2, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'e'): 1, ('s', 's'): 1, ('s', 'i'): 1, ('i', 'ng'): 3, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'e'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'p'): 1, ('l', 'i'): 2, ('i', 'c'): 1, ('c', 'a'): 1, ('t', 'i'): 2, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'i'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('ng', 'e'): 1, ('o', 'f'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'a'): 1, ('t', 'a'): 1})
# 2 80
# defaultdict(<class 'int'>, {('T', 'es'): 2, ('es', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'p'): 2, ('p', 'l'): 4, ('l', 'e'): 3, ('N', 'a'): 1, ('a', 't'): 3, ('t', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 2, ('a', 'l'): 2, ('l', 'a'): 3, ('a', 'ng'): 3, ('ng', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'i'): 1, ('i', 'ng'): 3, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'p'): 1, ('l', 'i'): 2, ('i', 'c'): 1, ('c', 'a'): 1, ('t', 'i'): 2, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'i'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('ng', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'a'): 1, ('t', 'a'): 1})
# 3 80
# defaultdict(<class 'int'>, {('T', 'es'): 2, ('es', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'a'): 1, ('a', 't'): 3, ('t', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 2, ('a', 'l'): 2, ('l', 'a'): 2, ('a', 'ng'): 3, ('ng', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'i'): 1, ('i', 'ng'): 3, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'a'): 1, ('t', 'i'): 2, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'i'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'i'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('ng', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'a'): 1, ('t', 'a'): 1})
# 4 80
# defaultdict(<class 'int'>, {('T', 'es'): 2, ('es', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 2, ('a', 'l'): 2, ('l', 'a'): 2, ('a', 'ng'): 3, ('ng', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'i'): 1, ('i', 'ng'): 3, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'i'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'i'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('ng', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 5 80
# defaultdict(<class 'int'>, {('T', 'es'): 2, ('es', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'i'): 1, ('i', 'ng'): 3, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'i'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'i'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 6 80
# defaultdict(<class 'int'>, {('T', 'es'): 2, ('es', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('t', 'e'): 3, ('e', 'c'): 2, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 't'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('e', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 7 80
# defaultdict(<class 'int'>, {('T', 'es'): 2, ('es', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 8 80
# defaultdict(<class 'int'>, {('Tes', 't'): 2, ('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 9 80
# defaultdict(<class 'int'>, {('s', 'a'): 2, ('a', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 10 80
# defaultdict(<class 'int'>, {('sa', 'm'): 2, ('m', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 11 80
# defaultdict(<class 'int'>, {('sam', 'pl'): 2, ('pl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 12 80
# defaultdict(<class 'int'>, {('sampl', 'e'): 2, ('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 13 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'a'): 1, ('a', 'l'): 2, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'a'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 14 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('l', 'ang'): 2, ('ang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 15 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('lang', 'u'): 2, ('u', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 16 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('langu', 'a'): 2, ('a', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 17 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('langua', 'g'): 2, ('g', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('g', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 18 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'r'): 1, ('r', 'o'): 2, ('o', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('o', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 19 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('i', 'n'): 2, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 20 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'o'): 1, ('o', 'd'): 2, ('d', 'e'): 2, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'o'): 1, ('d', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 21 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'a'): 1, ('a', 'n'): 2, ('n', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 22 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'an'): 1, ('an', 'd'): 2, ('d', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 23 80
# defaultdict(<class 'int'>, {('N', 'at'): 1, ('at', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 24 80
# defaultdict(<class 'int'>, {('Nat', 'u'): 1, ('u', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 25 80
# defaultdict(<class 'int'>, {('Natu', 'r'): 1, ('r', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 26 80
# defaultdict(<class 'int'>, {('Natur', 'al'): 1, ('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 27 80
# defaultdict(<class 'int'>, {('languag', 'e'): 1, ('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 28 80
# defaultdict(<class 'int'>, {('p', 'ro'): 1, ('ro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 29 80
# defaultdict(<class 'int'>, {('pro', 'c'): 1, ('c', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 30 80
# defaultdict(<class 'int'>, {('proc', 'es'): 1, ('es', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 31 80
# defaultdict(<class 'int'>, {('proces', 's'): 1, ('s', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 32 80
# defaultdict(<class 'int'>, {('process', 'ing'): 1, ('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 33 80
# defaultdict(<class 'int'>, {('te', 'c'): 1, ('c', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 34 80
# defaultdict(<class 'int'>, {('tec', 'h'): 1, ('h', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 35 80
# defaultdict(<class 'int'>, {('tech', 'n'): 1, ('n', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 36 80
# defaultdict(<class 'int'>, {('techn', 'i'): 1, ('i', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 37 80
# defaultdict(<class 'int'>, {('techni', 'q'): 1, ('q', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 38 80
# defaultdict(<class 'int'>, {('techniq', 'u'): 1, ('u', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 39 80
# defaultdict(<class 'int'>, {('techniqu', 'es'): 1, ('pl', 'a'): 1, ('a', 'y'): 1, ('c', 'r'): 1, ('r', 'u'): 1, ('u', 'c'): 1, ('c', 'i'): 1, ('i', 'al'): 1, ('ro', 'l'): 1, ('l', 'e'): 1, ('m', 'od'): 1, ('od', 'e'): 1, ('e', 'r'): 1, ('r', 'n'): 1, ('A', 'I'): 1, ('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# ...
# 54 80
# defaultdict(<class 'int'>, {('a', 'p'): 1, ('p', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 55 80
# defaultdict(<class 'int'>, {('ap', 'pl'): 1, ('pl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 56 80
# defaultdict(<class 'int'>, {('appl', 'i'): 1, ('i', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 57 80
# defaultdict(<class 'int'>, {('appli', 'c'): 1, ('c', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 58 80
# defaultdict(<class 'int'>, {('applic', 'at'): 1, ('at', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 59 80
# defaultdict(<class 'int'>, {('applicat', 'i'): 1, ('i', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 60 80
# defaultdict(<class 'int'>, {('applicati', 'o'): 1, ('o', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 61 80
# defaultdict(<class 'int'>, {('applicatio', 'n'): 1, ('n', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 62 80
# defaultdict(<class 'int'>, {('application', 's'): 1, ('s', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 63 80
# defaultdict(<class 'int'>, {('applications', '\n'): 1, ('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 64 80
# defaultdict(<class 'int'>, {('B', 'y'): 1, ('y', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 65 80
# defaultdict(<class 'int'>, {('By', 'te'): 1, ('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 66 80
# defaultdict(<class 'int'>, {('P', 'a'): 1, ('a', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 67 80
# defaultdict(<class 'int'>, {('Pa', 'i'): 1, ('i', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 68 80
# defaultdict(<class 'int'>, {('Pai', 'r'): 1, ('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 69 80
# defaultdict(<class 'int'>, {('E', 'n'): 1, ('n', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 70 80
# defaultdict(<class 'int'>, {('En', 'c'): 1, ('c', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 71 80
# defaultdict(<class 'int'>, {('Enc', 'od'): 1, ('od', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 72 80
# defaultdict(<class 'int'>, {('Encod', 'ing'): 1, ('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 73 80
# defaultdict(<class 'int'>, {('i', 's'): 1, ('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 74 80
# defaultdict(<class 'int'>, {('e', 'f'): 1, ('f', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 75 80
# defaultdict(<class 'int'>, {('ef', 'f'): 1, ('f', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 76 80
# defaultdict(<class 'int'>, {('eff', 'e'): 1, ('e', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 77 80
# defaultdict(<class 'int'>, {('effe', 'c'): 1, ('c', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 78 80
# defaultdict(<class 'int'>, {('effec', 't'): 1, ('t', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 79 80
# defaultdict(<class 'int'>, {('effect', 'i'): 1, ('i', 'v'): 1, ('v', 'e'): 1, ('h', 'and'): 1, ('and', 'l'): 1, ('l', 'ing'): 1, ('w', 'i'): 1, ('i', 'd'): 1, ('d', 'e'): 1, ('r', 'ang'): 1, ('ang', 'e'): 1, ('o', 'f'): 1, ('languag', 'es'): 1, ('te', 'x'): 1, ('x', 't'): 1, ('d', 'at'): 1, ('at', 'a'): 1})
# 80
# ['i',
#  's',
#  't',
#  'and',
#  'h',
#  'e',
#  'r',
#  'e',
#  'i',
#  'f',
#  'e',
#  'e',
#  'l',
#  'e',
#  'm',
#  'p',
#  't',
#  'y',
#  'a',
#  'c',
#  'l',
#  'a',
#  's',
#  's',
#  'p',
#  'o',
#  's',
#  't',
#  'c',
#  'o',
#  'u',
#  'n',
#  't',
#  'l',
#  'in',
#  'k',
#  'h',
#  'r',
#  'ef',
#  'h',
#  't',
#  't',
#  'p',
#  'm',
#  'o',
#  'o',
#  's',
#  'h',
#  'i',
#  'l',
#  'u',
#  '\n',
#  'i',
#  'l',
#  'i',
#  'te',
#  'r',
#  'al',
#  'l',
#  'y',
#  'j',
#  'u',
#  's',
#  't',
#  'te',
#  'x',
#  't',
#  't',
#  'y',
#  'c',
#  'h',
#  'e',
#  'l',
#  'l',
#  'e',
#  't',
#  'o',
#  's',
#  'e',
#  'e',
#  'i',
#  'f',
#  's',
#  'h',
#  'e',
#  'w',
#  'an',
#  't',
#  's',
#  't',
#  'o',
#  'h',
#  'ang',
#  'o',
#  'u',
#  't',
#  'b',
#  'e',
#  'c',
#  'a',
#  'u',
#  's',
#  'e',
#  'r',
#  'e',
#  'a',
#  'd',
#  'ing',
#  'w',
#  'h',
#  'at',
#  'i',
#  'j',
#  'u',
#  's',
#  't',
#  'w',
#  'ro',
#  'te',
#  'a',
#  'b',
#  'o',
#  'u',
#  't',
#  'm',
#  'y',
#  'n',
#  'o',
#  'n',
#  'e',
#  'x',
#  'is',
#  'te',
#  'n',
#  't',
#  's',
#  'o',
#  'c',
#  'i',
#  'al',
#  'l',
#  'i',
#  'f',
#  'e',
#  'm',
#  'a',
#  'd',
#  'e',
#  'm',
#  'e',
#  'f',
#  'e',
#  'e',
#  'l',
#  's',
#  'o',
#  'p',
#  'at',
#  'h',
#  'e',
#  't',
#  'i',
#  'c',
#  '\n',
#  'i',
#  'r',
#  'e',
#  'al',
#  'l',
#  'y',
#  'f',
#  'e',
#  'e',
#  'l',
#  'r',
#  'e',
#  'g',
#  'r',
#  'e',
#  't',
#  'f',
#  'u',
#  'l',
#  'w',
#  'h',
#  'e',
#  'n',
#  'h',
#  'e',
#  'a',
#  'r',
#  'ing',
#  't',
#  'h',
#  'at',
#  's',
#  'h',
#  'in',
#  'a',
#  'e',
#  'g',
#  'o',
#  't',
#  'm',
#  'a',
#  'r',
#  'r',
#  'i',
#  'e',
#  'd',
#  't',
#  'o',
#  'an',
#  'o',
#  't',
#  'h',
#  'e',
#  'r',
#  'm',
#  'an',
#  'o',
#  'h',
#  'i',
#  't',
#  's',
#  'r',
#  'e',
#  'al',
#  'l',
#  'y',
#  'sa',
#  'd',
#  'i',
#  'r',
#  'e',
#  'al',
#  'l',
#  'y',
#  'h',
#  'o',
#  'p',
#  'e',
#  't',
#  'h',
#  'at',
#  'al',
#  'e',
#  'x',
#  'and',
#  's',
#  'h',
#  'in',
#  'a',
#  'e',
#  'c',
#  'an',
#  'b',
#  'e',
#  'a',
#  'c',
#  'o',
#  'u',
#  'pl',
#  'e',
#  'in',
#  'r',
#  'e',
#  'al',
#  'l',
#  'i',
#  'f',
#  'e',
#  't',
#  'h',
#  'e',
#  'y',
#  'r',
#  'e',
#  'p',
#  'e',
#  'r',
#  'f',
#  'e',
#  'c',
#  't',
#  'f',
#  'o',
#  'r',
#  'e',
#  'a',
#  'c',
#  'h',
#  'o',
#  't',
#  'h',
#  'e',
#  'r',
#  '\n',
#  'i',
#  'b',
#  'e',
#  'l',
#  'i',
#  'e',
#  'v',
#  'e',
#  'd',
#  'i',
#  't',
#  'w',
#  'a',
#  's',
#  't',
#  'r',
#  'u',
#  'e',
#  'l',
#  'o',
#  'v',
#  'e',
#  'and',
#  'f',
#  'e',
#  'e',
#  'l',
#  'd',
#  'e',
#  'v',
#  'a',
#  's',
#  't',
#  'at',
#  'e',
#  'd',
#  'i',
#  'w',
#  'an',
#  'te',
#  'd',
#  't',
#  'o',
#  's',
#  'e',
#  't',
#  't',
#  'l',
#  'e',
#  'd',
#  'o',
#  'w',
#  'n',
#  'and',
#  'h',
#  'a',
#  'v',
#  'e',
#  't',
#  'h',
#  'e',
#  'w',
#  'h',
#  'o',
#  'l',
#  'e',
#  'm',
#  'a',
#  'r',
#  'r',
#  'i',
#  'a',
#  'g',
#  'e',
#  'and',
#  'k',
#  'i',
#  'd',
#  's',
#  't',
#  'h',
#  'ing',
#  'w',
#  'i',
#  't',
#  'h',
#  'h',
#  'i',
#  'm',
#  '\n',
#  'i',
#  'f',
#  'e',
#  'e',
#  'l',
#  'u',
#  'n',
#  'i',
#  'm',
#  'p',
#  'o',
#  'r',
#  't',
#  'an',
#  't',
#  's',
#  'o',
#  'in',
#  'a',
#  'd',
#  'e',
#  'q',
#  'u',
#  'at',
#  'e',
#  '\n',
#  'i',
#  'f',
#  'e',
#  'e',
#  'l',
#  'v',
#  'e',
#  'r',
#  'y',
#  'l',
#  'o',
#  'w',
#  'al',
#  'r',
#  'e',
#  'a',
#  'd',
#  'y']

# %% [markdown]
# ## Question 2

# %%
import numpy as np
from collections import defaultdict

class BigramLM:
    def __init__(self, vocabulary):
        self.vocabulary = vocabulary
        self.bigram_counts = defaultdict(lambda: defaultdict(int))
        self.unigram_counts = defaultdict(int)
        self.total_bigrams = 0

    def learn_model(self, dataset):
        for sentence in dataset:
            sentence = ["<s>"] + sentence + ["</s>"]
            for i in range(len(sentence) - 1):
                self.bigram_counts[sentence[i]][sentence[i+1]] += 1
                self.unigram_counts[sentence[i]] += 1
                self.total_bigrams += 1

    def laplace_smoothing(self, bigram, alpha=1):
        numerator = self.bigram_counts[bigram[0]][bigram[1]] + alpha
        denominator = self.unigram_counts[bigram[0]] + (len(self.vocabulary) * alpha)
        return numerator / denominator

    def kneser_ney_smoothing(self, bigram, discount=0.75):
        prefix_count = self.unigram_counts[bigram[0]]
        continuation_count = len(self.bigram_counts[bigram[0]])

        # Kneser-Ney smoothing formula
        prob = max(self.bigram_counts[bigram[0]][bigram[1]] - discount, 0) / prefix_count
        prob += (discount / prefix_count) * continuation_count * (1 / self.total_bigrams)
        return prob

if __name__ == "__main__":
    # Example usage
    training_data = [
        ["I", "love", "programming"],
        ["Programming", "is", "fun"],
        ["Machine", "learning", "is", "exciting"]
    ]

    vocabulary = set(word for sentence in training_data for word in sentence)

    bigram_lm = BigramLM(vocabulary)
    bigram_lm.learn_model(training_data)

    test_bigram = ("Programming", "is")

    laplace_prob = bigram_lm.laplace_smoothing(test_bigram)
    kneser_ney_prob = bigram_lm.kneser_ney_smoothing(test_bigram)

    print(f"Laplace Smoothing Probability: {laplace_prob}")
    print(f"Kneser-Ney Smoothing Probability: {kneser_ney_prob}")
# Out:
# Laplace Smoothing Probability: 0.2
# Kneser-Ney Smoothing Probability: 0.3076923076923077

# %% [markdown]
# ## Why kneser ney is better than laplace smoothing
# Kneser ney is uses discounting method to reduce the probability mass assigned to frequent bigrams and redistribute it to unseen bigrams. This is better than laplace smoothing because laplace smoothing assigns equal probability to all unseen bigrams which is not a good way to estimate the probability of unseen bigrams.

# %%
from utils import emotion_scores

print(emotion_scores("I am happy"))
# Out:
# [{'label': 'sadness', 'score': 0.0005438437219709158}, {'label': 'joy', 'score': 0.998437225818634}, {'label': 'love', 'score': 0.0004561925888992846}, {'label': 'anger', 'score': 0.00026224859175272286}, {'label': 'fear', 'score': 0.0001431150158168748}, {'label': 'surprise', 'score': 0.00015750851889606565}]

# %%
import random
from collections import defaultdict

class BigramLanguageModel:
    def __init__(self):
        self.bigrams = defaultdict(list)
        self.start_tokens = []

    def train(self, corpus):
        # Assuming the corpus is a list of sentences
        for sentence in corpus:
            tokens = sentence.split()
            self.start_tokens.append(tokens[0])
            for i in range(len(tokens) - 1):
                current_token = tokens[i]
                next_token = tokens[i + 1]
                self.bigrams[current_token].append(next_token)

    def generate_sentence(self, length=10):
        sentence = []
        current_token = random.choice(self.start_tokens)

        for _ in range(length):
            sentence.append(current_token)
            possible_next_tokens = self.bigrams[current_token]

            if not possible_next_tokens:
                break

            current_token = random.choice(possible_next_tokens)

        return ' '.join(sentence)

sentence = []
label = []
with open('corpus.txt', encoding="utf8") as f:
    for line in f:
        sentence.append(line)
with open('labels.txt', encoding="utf8") as f:
    for line in f:
        label.append(line)
corpus = [sentence[i] + label[i] for i in range(len(sentence))]

bigram_lm = BigramLanguageModel()
bigram_lm.train(corpus)

generated_sentence = bigram_lm.generate_sentence()
print(generated_sentence)
# Out:
# i still feel stressed about the sentence i think that

# %%
from utils import emotion_scores
class EmotionBigramLanguageModel(BigramLanguageModel):
    def __init__(self, beta=0.1):
        super().__init__()
        self.emotions = defaultdict(list)
        self.beta = beta

    def train_emotions(self, emotions):
        # Assuming emotions is a list of tuples (sentence, emotion)
        for sentence, emotion in emotions:
            tokens = sentence.split()
            self.start_tokens.append(tokens[0])  # Add the first token to start_tokens
            for i in range(len(tokens) - 1):
                current_token = tokens[i]
                next_token = tokens[i + 1]
                self.bigrams[current_token].append(next_token)
                self.emotions[current_token].append(emotion)

    def emotion_score(self, sentence):
        # emotion_scores(sentence)
        return 0.5

    def calculate_probability(self, current_token, next_token):
        # Calculate the probability with emotional component
        count_current = len(self.bigrams[current_token])
        count_bigram = self.bigrams[current_token].count(next_token)
        emotion_component = self.beta * self.emotion_score(current_token)

        probability = (count_bigram / count_current) + emotion_component
        return probability

    def generate_emotion_sentence(self, target_emotion, length=20):
        sentence = []
        current_token = random.choice(self.start_tokens)
        # print("current_token", current_token)

        for _ in range(length):
            sentence.append(current_token)
            possible_next_tokens = self.bigrams[current_token]
            # print(possible_next_tokens)
            if not possible_next_tokens:
                break

            probabilities = [self.calculate_probability(current_token, next_token) for next_token in possible_next_tokens]
            # print(probabilities)
            current_token = random.choices(possible_next_tokens, weights=probabilities)[0]
            # print("current_token", current_token)
            # Check if the generated token has the target emotion
            if current_token in self.emotions and target_emotion in self.emotions[current_token]:
                break

        return ' '.join(sentence), target_emotion

# Example usage:
sentences = []
labels = []
with open('corpus.txt', encoding="utf8") as f:
    for line in f:
        sentences.append(line)
with open('labels.txt', encoding="utf8") as f:
    for line in f:
        labels.append(line)
emotions = list(set(labels))
print(emotions)
emotion_corpus = list(zip(sentences, labels))

emotion_bigram_lm = EmotionBigramLanguageModel()
emotion_bigram_lm.train_emotions(emotion_corpus)

target_emotions  = []
for i in range(len(emotions)):
    for j in range(50):
        target_emotions.append(emotions[i])
print("Number of target emotions: ", len(target_emotions))

gens = []
for i in range(len(target_emotions)):
    if i%50 == 0:
        print(i)
    generated_emotion_sentence, generated_emotion = emotion_bigram_lm.generate_emotion_sentence(target_emotions[i])
    print(f"Generated Sentence: {generated_emotion_sentence}\nEmotion: {generated_emotion}")
    gens.append(generated_emotion_sentence)
print("Number of generated sentences: ", len(gens))
# generated_emotion_sentence, generated_emotion = emotion_bigram_lm.generate_emotion_sentence(target_emotion)
# print(f"Generated Sentence: {generated_emotion_sentence}\nEmotion: {generated_emotion}")
# Out:
# ['fear\n', 'joy\n', 'surprise\n', 'love\n', 'anger\n', 'sadness\n']
# Number of target emotions:  300
# 0
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: im
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: i
# Emotion: fear
#
# Generated Sentence: ive
# Emotion: fear
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [264], in <cell line: 77>()
#      78 if i%50 == 0:
#      79     print(i)
# ---> 80 generated_emotion_sentence, generated_emotion = emotion_bigram_lm.generate_emotion_sentence(target_emotions[i])
#      81 print(f"Generated Sentence: {generated_emotion_sentence}\nEmotion: {generated_emotion}")
#      82 gens.append(generated_emotion_sentence)
#
# Input In [264], in EmotionBigramLanguageModel.generate_emotion_sentence(self, target_emotion, length)
#      41 if not possible_next_tokens:
#      42     break
# ---> 44 probabilities = [self.calculate_probability(current_token, next_token) for next_token in possible_next_tokens]
#      45 # print(probabilities)
#      46 current_token = random.choices(possible_next_tokens, weights=probabilities)[0]
#
# Input In [264], in <listcomp>(.0)
#      41 if not possible_next_tokens:
#      42     break
# ---> 44 probabilities = [self.calculate_probability(current_token, next_token) for next_token in possible_next_tokens]
#      45 # print(probabilities)
#      46 current_token = random.choices(possible_next_tokens, weights=probabilities)[0]
#
# Input In [264], in EmotionBigramLanguageModel.calculate_probability(self, current_token, next_token)
#      25 count_current = len(self.bigrams[current_token])
#      26 count_bigram = self.bigrams[current_token].count(next_token)
# ---> 27 emotion_component = self.beta * self.emotion_score(current_token)
#      29 probability = (count_bigram / count_current) + emotion_component
#      30 return probability
#
# Input In [264], in EmotionBigramLanguageModel.emotion_score(self, sentence)
#      16             self.bigrams[current_token].append(next_token)
#      17             self.emotions[current_token].append(emotion)
# ---> 19 def emotion_score(self, sentence):
#      20     # emotion_scores(sentence)
#      21     return 0.5
#      23 def calculate_probability(self, current_token, next_token):
#      24     # Calculate the probability with emotional component
#
# KeyboardInterrupt:

# %%
# save gens to file
with open('generated_sentences.txt', 'w', encoding="utf8") as f:
    for item in gens:
        f.write(item)
        f.write("\n")

with open('target_emotions.txt', 'w', encoding="utf8") as f:
    for item in target_emotions:
        f.write(item)
        f.write("\n")

# %%
from utils import emotion_scores

# print(emotion_scores(generated_emotion_sentence))
for i in range(1):
    a = emotion_scores(gens[i])
    # print(a)
    d = {}
    for i in a:
        d[i['label']] = i['score']
    # print(d)
    # print the emotion which has the highest score
    for key, value in d.items():
        if value == max(d.values()):
            print(key)
# Out:
# love

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

# Sample data
corpus = [
    ("I love spending time with my family.", "joy"),
    ("The news about the accident is so sad.", "sadness"),
    # Add more sentences and labels as needed
]

# Tokenization and emotional component extraction
tokens_with_emotion = []

for sentence, emotion in corpus:
    # Tokenize the sentence
    tokens = word_tokenize(sentence.lower())  # Convert to lowercase for consistency

    # Remove stop words (optional, depends on your use case)
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token.isalnum() and token not in stop_words]

    # Append the emotional component to each token
    tokens_with_emotion.extend([(token, emotion) for token in tokens])

# Print the result
for token, emotion in tokens_with_emotion:
    print(f"Token: {token}, Emotion: {emotion}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vartika\AppData\Roaming\nltk_data...
# Token: love, Emotion: joy
# Token: spending, Emotion: joy
# Token: time, Emotion: joy
# Token: family, Emotion: joy
# Token: news, Emotion: sadness
# Token: accident, Emotion: sadness
# Token: sad, Emotion: sadness
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vartika\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report
X_train = []
with open('corpus.txt', encoding="utf8") as f:
    for line in f:
        X_train.append(line)
y_train = []
with open('labels.txt', encoding="utf8") as f:
    for line in f:
        y_train.append(line)
# x_test = []
# with open('generated_sentences.txt', encoding="utf8") as f:
#     for line in f:
#         x_test.append(line)
# y_test = []
# with open('target_emotions.txt', encoding="utf8") as f:
#     for line in f:
#         y_test.append(line)
# Initialize TF-IDF vectorizer
X_train, x_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

tfidf_vectorizer = TfidfVectorizer()

# Fit and transform on the training data
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)

# Transform the test data using the same vectorizer
X_test_tfidf = tfidf_vectorizer.transform(x_test)
# Define parameter grid for Grid Search
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['linear', 'rbf', 'poly', 'sigmoid']}

# Initialize SVC
svc = SVC()

# Perform Grid Search with 5-fold cross-validation
grid_search = GridSearchCV(svc, param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train_tfidf, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Train SVC with the best parameters obtained from Grid Search
best_svc = SVC(C=best_params['C'], gamma=best_params['gamma'], kernel=best_params['kernel'])
best_svc.fit(X_train_tfidf, y_train)
# Predict using the trained model
y_pred = best_svc.predict(X_test_tfidf)

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Classification Report:
#                precision    recall  f1-score   support
#
#       anger
#        0.79      0.73      0.76        75
#        fear
#        0.75      0.75      0.75        77
#         joy
#        0.66      0.73      0.69        88
#        love
#        0.76      0.84      0.80        80
#     sadness
#        0.73      0.65      0.69        80
#    surprise
#        0.94      0.90      0.92        80
#
#     accuracy                           0.77       480
#    macro avg       0.77      0.77      0.77       480
# weighted avg       0.77      0.77      0.77       480

# %%
# test the model with generated sentences
x_test = []
with open('generated_sentences.txt', encoding="utf8") as f:
    for line in f:
        x_test.append(line)
print(len(x_test))

y_test = []
with open('target_emotions.txt', encoding="utf8") as f:
    for line in f:
        y_test.append(line)
# Transform the test data using the same vectorizer
X_test_tfidf = tfidf_vectorizer.transform(x_test)
print(len(X_test_tfidf))
# Predict using the trained model
y_pred = best_svc.predict(X_test_tfidf)
print(len(y_pred), len(y_test))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [262], in <cell line: 14>()
#      12 # Transform the test data using the same vectorizer
#      13 X_test_tfidf = tfidf_vectorizer.transform(x_test)
# ---> 14 print(len(X_test_tfidf))
#      15 # Predict using the trained model
#      16 y_pred = best_svc.predict(X_test_tfidf)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_base.py:345, in spmatrix.__len__(self)
#     344 def __len__(self):
# --> 345     raise TypeError("sparse matrix length is ambiguous; use getnnz()"
#     346                     " or shape[0]")
#
# TypeError: sparse matrix length is ambiguous; use getnnz() or shape[0]

# %%
import pandas as pd

# %%
sentences = []
labels = []
with open('corpus.txt', encoding="utf8") as f:
    for line in f:
        sentences.append(line.strip())

with open('labels.txt', encoding="utf8") as f:
    for line in f:
        labels.append(line.strip())

df = pd.DataFrame({'sentences': sentences, 'labels': labels})
# print(df.head())
# sample 20 for each label
# print(df['labels'].value_counts())
df_sampled = df.groupby('labels').apply(lambda x: x.sample(20)).reset_index(drop=True)
# choose only anger joy and sadness
# df_sampled = df[df['labels'].isin(['anger'])]
# print(df_sampled.head())
print(df_sampled.head(1200))
# print number of samples for each label
# print(df_sampled['labels'].value_counts())

# save the sampled data in a trail.txt
with open('trail.txt', 'w', encoding="utf8") as f:
    for index, row in df_sampled.iterrows():
        f.write(row['sentences'] + '\n')
# Out:
#                                              sentences    labels
# 0    i mean their puzzle section is about on par wi...     anger
# 1    im dreaming of zombie apocalypses alien dragon...     anger
# 2    i feel about gift cards they re after thoughts...     anger
# 3    i never thought id feel so much as a jot of sy...     anger
# 4                    i feel less bitchy in the morning     anger
# ..                                                 ...       ...
# 115  i know im making a big deal out of it but i fe...  surprise
# 116  i always tell people my brd armor sucks since ...  surprise
# 117  i feel about politics and i have been very sho...  surprise
# 118  i haven t seen her since they broke up but now...  surprise
# 119  i sit down to author this letter i feel a litt...  surprise
#
# [120 rows x 2 columns]

# %%
import numpy as np
import pickle
from utils import emotion_scores


import warnings
warnings.filterwarnings("ignore")

class BigramLM:
    def __init__(self, file, smoothing = 2):

        self.tokens = set()
        self.data = ""

        with open(file, 'r') as fil:
            data = fil.read()
        lin_data = data.split("\n")
        for sntc in lin_data:
            fsntc = f'<s> {sntc} <e> '
            self.data += fsntc
            self.tokens.update(fsntc.split())

        self.tok_id = {token: index for index, token in enumerate(self.tokens)}

        self.id_tok = {index: token for token, index in self.tok_id.items()}
        self.tokenized = self.get_tokens(self.data)

        self.coeff_mat, self.sad_mat, self.joy_mat, self.lov_mat, self.ang_mat, self.fea_mat, self.sup_mat = self.gen_matrix(self.tokenized)

        if(smoothing == 1):
            self.prob_mat = self.laplace_mat()
        elif(smoothing == 2):
            self.prob_mat = self.kneser_ney_mat()
        else:
            self.prob_mat = self.create_mat()


    def get_tokens(self, seq):
        toks = seq.split()
        return [self.tok_id[tok] for tok in toks]

    def get_seq(self, ids):
        tokid = [self.id_tok[id] for id in ids]
        sent = " ".join(tokid)
        return sent

    def create_mat(self):
        return self.coeff_mat/self.coeff_mat.sum(1, keepdims=True)

    def laplace_mat(self):
        prob_mt = self.coeff_mat + 1
        return prob_mt/prob_mt.sum(1, keepdims=True)

    def kneser_ney_mat(self, d = 0.75):
        prob_mt = self.coeff_mat
        frst_trm = np.maximum(prob_mt - d, 0)/prob_mt.sum(1, keepdims=True)
        lmbd_trm = (d/prob_mt.sum(axis = 1,keepdims=True)) * np.count_nonzero(prob_mt, axis=1, keepdims=True)
        cont = np.count_nonzero(prob_mt, axis=0, keepdims=True)
        pcnt_trm = cont/ cont.sum()
        return frst_trm + lmbd_trm * pcnt_trm

    def genrate(self, emotion, size = -1):
        idx = self.get_tokens("<s>")[0]
        generated_sequence = ""
        i = 0
        if emotion == 'sad':
            mat = self.sad_mat
        elif emotion == 'joy':
            mat = self.joy_mat
        elif emotion == 'love':
            mat = self.lov_mat
        elif emotion == 'angry':
            mat = self.ang_mat
        elif emotion == 'fear':
            mat = self.fea_mat
        elif emotion == 'surprise':
            mat = self.sup_mat
        else:
            mat = np.zeros_like(self.coeff_mat)

        curr_mat = self. prob_mat + mat
        curr_mat /= curr_mat.sum(1, keepdims=True)

        while self.get_seq([idx]) != "<e>":
            if i == size:
                generated_sequence += "."
                break
            elif(i != 0):
                generated_sequence += self.get_seq([idx]) + " "
            p = curr_mat[idx]
            idx = int(np.random.choice(len(p), p=p))
            i += 1
        return generated_sequence

    def gen_matrix(self, tokens):
        max_tkn = max(tokens) + 1
        coeff_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        sad_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        joy_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        lov_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        ang_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        fea_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        sup_mat = np.zeros((max_tkn, max_tkn), dtype=np.float64)
        for t1, t2 in zip(tokens, tokens[1:]):
            coeff_mat[t1, t2] += 1
            if(coeff_mat[t1, t2] == 1):
                emote = emotion_scores(self.get_seq([t1,t2]))
                # check index for which score is max
                scores = [emote[i]['score'] for i in range(6)]
                max_idx = scores.index(max(scores))
                # if max_idx ==0:
                    # sad_mat[t1, t2] = 3
                # if max_idx ==1:
                    # joy_mat[t1, t2] = 2
                if max_idx ==3:
                    ang_mat[t1, t2] = 2
                sad_mat[t1, t2] += emote[0]['score']
                joy_mat[t1, t2] += emote[1]['score']
                lov_mat[t1, t2] = emote[2]['score']
                ang_mat[t1, t2] = emote[3]['score']
                fea_mat[t1, t2] = emote[4]['score']
                sup_mat[t1, t2] = emote[5]['score']
        return coeff_mat, sad_mat, joy_mat, lov_mat, ang_mat, fea_mat, sup_mat



    def save(self, filename = "bigram_mdl.pkl"):
        with open(filename, 'wb') as f:
            pickle.dump(self, f)

    def get_emotion_score(self, size = -1, emotion = None):
        sntnc = self.genrate(emotion, size = size)
        emt_scr = emotion_scores(sntnc)
        emote = max(emt_scr, key=lambda x: x['score'])
        return sntnc, emote["label"], emote["score"]





def load(filename = "bigram_mdl.pkl"):
        with open(filename, 'rb') as f:
            obj = pickle.load(f)
        return obj



# bgram = load()
#

# bgram = BigramLM("corpus.txt")
bgram = BigramLM("trail.txt")
bgram.save()
# emotions = ["sad", "joy", "love", "anger", "fear", "surprise"]
# test_labels = []
# for i in emotions:
#     for j in range(50):
#         test_labels.append(i)
# test_corpus = []
# for i in test_labels:
#     sent, label, score = bgram.get_emotion_score(size = 50, emotion=i)
#     # print(score)
#     test_corpus.append(sent[14:])

# %%
bgram = load()

emotions = ["sadness", "joy", "love", "anger", "fear", "surprise"]
# emotions = ['anger']
test_labels = []
for i in emotions:
    for j in range(50):
        test_labels.append(i)
test_corpus = []
count_low_conf = []
for i in test_labels:
    sent, label, score = bgram.get_emotion_score(size = 10, emotion=i)
    if score<0.99:
        print(label,score,"\n")
    test_corpus.append(sent[14:])
a = len(set(test_corpus))
print(len(test_corpus))
print(a)
# Out:
# anger 0.7600669264793396
#
# joy 0.554580569267273
#
# joy 0.5786640048027039
#
# surprise 0.9899387359619141
#
# anger 0.9874909520149231
#
# anger 0.7474933862686157
#
# joy 0.7359861731529236
#
# anger 0.9023003578186035
#
# surprise 0.9804447889328003
#
# anger 0.7634316086769104
#
# joy 0.9883244037628174
#
# anger 0.808184802532196
#
# joy 0.9278499484062195
#
# anger 0.5931628346443176
#
# joy 0.6334918141365051
#
# fear 0.9030251502990723
#
# anger 0.6642425060272217
#
# anger 0.48309192061424255
#
# joy 0.9540638327598572
#
# anger 0.8207505941390991
#
# fear 0.8708183765411377
#
# joy 0.8870062828063965
#
# surprise 0.8766688704490662
#
# sadness 0.9441691040992737
#
# joy 0.8949677348136902
#
# anger 0.9139100909233093
#
# anger 0.6868834495544434
#
# anger 0.7121037840843201
#
# joy 0.9745725393295288
#
# joy 0.9298902750015259
#
# sadness 0.5841748714447021
#
# joy 0.8047534227371216
#
# joy 0.686432957649231
#
# anger 0.47305986285209656
#
# joy 0.9892922639846802
#
# joy 0.9609902501106262
#
# anger 0.47305986285209656
#
# joy 0.6569898724555969
#
# love 0.7258548736572266
#
# fear 0.6310291290283203
#
# anger 0.6798689365386963
#
# anger 0.47305986285209656
#
# joy 0.9657731652259827
#
# joy 0.9874310493469238
#
# joy 0.9188112616539001
#
# anger 0.7991123199462891
#
# anger 0.47305986285209656
#
# joy 0.9847298264503479
#
# anger 0.9217926263809204
#
# joy 0.9607229232788086
#
# fear 0.9002938866615295
#
# anger 0.47305986285209656
#
# joy 0.9666292667388916
#
# love 0.5313161611557007
#
# anger 0.8177513480186462
#
# joy 0.7930874228477478
#
# anger 0.9784104228019714
#
# sadness 0.9818111062049866
#
# joy 0.9856612682342529
#
# joy 0.9879891872406006
#
# fear 0.529658317565918
#
# joy 0.8956383466720581
#
# joy 0.9710108041763306
#
# anger 0.49410077929496765
#
# sadness 0.95646733045578
#
# love 0.9784772992134094
#
# joy 0.6662578582763672
#
# anger 0.897145688533783
#
# joy 0.9706345200538635
#
# anger 0.4525507390499115
#
# joy 0.7125987410545349
#
# anger 0.420917809009552
#
# joy 0.773362934589386
#
# anger 0.9195669889450073
#
# love 0.9199604392051697
#
# anger 0.7833446860313416
#
# love 0.9207048416137695
#
# joy 0.9297777414321899
#
# love 0.9600035548210144
#
# joy 0.5760626196861267
#
# love 0.8472402691841125
#
# joy 0.970247209072113
#
# joy 0.9766448736190796
#
# joy 0.4644310772418976
#
# joy 0.8088927268981934
#
# joy 0.9251266121864319
#
# joy 0.9812596440315247
#
# surprise 0.9897807836532593
#
# joy 0.9577608704566956
#
# anger 0.8813679218292236
#
# joy 0.739913284778595
#
# joy 0.6931489109992981
#
# sadness 0.42859601974487305
#
# fear 0.8705512881278992
#
# joy 0.9724173545837402
#
# anger 0.9235104918479919
#
# joy 0.7449591755867004
#
# joy 0.8236020803451538
#
# anger 0.7711118459701538
#
# joy 0.9897450804710388
#
# anger 0.765916645526886
#
# fear 0.9549239873886108
#
# anger 0.7187660336494446
#
# anger 0.7334690093994141
#
# joy 0.9051536321640015
#
# joy 0.9858514666557312
#
# joy 0.9401755332946777
#
# sadness 0.6771839261054993
#
# joy 0.9863524436950684
#
# joy 0.9803087711334229
#
# anger 0.9200951457023621
#
# joy 0.9003286957740784
#
# fear 0.6839787364006042
#
# anger 0.47305986285209656
#
# fear 0.4688008427619934
#
# joy 0.7700885534286499
#
# anger 0.47305986285209656
#
# fear 0.6865741014480591
#
# fear 0.5083801746368408
#
# joy 0.9627187252044678
#
# fear 0.3832830488681793
#
# anger 0.813565194606781
#
# joy 0.8543875813484192
#
# joy 0.9853938817977905
#
# anger 0.47305986285209656
#
# anger 0.47305986285209656
#
# surprise 0.6499635577201843
#
# fear 0.8644153475761414
#
# anger 0.9011032581329346
#
# sadness 0.9849067330360413
#
# anger 0.8173143267631531
#
# anger 0.47305986285209656
#
# love 0.7256191372871399
#
# anger 0.47305986285209656
#
# surprise 0.9864253997802734
#
# sadness 0.5230007767677307
#
# joy 0.7453230619430542
#
# joy 0.7256858348846436
#
# anger 0.674917995929718
#
# anger 0.728560209274292
#
# fear 0.8494130373001099
#
# anger 0.47305986285209656
#
# fear 0.43349698185920715
#
# fear 0.5793444514274597
#
# anger 0.47305986285209656
#
# anger 0.40179359912872314
#
# anger 0.47305986285209656
#
# anger 0.8642483353614807
#
# joy 0.8882262706756592
#
# anger 0.8298606276512146
#
# joy 0.9779232740402222
#
# fear 0.536243736743927
#
# anger 0.6341497898101807
#
# joy 0.9522818326950073
#
# joy 0.9601485133171082
#
# joy 0.8132628798484802
#
# surprise 0.7871381640434265
#
# surprise 0.6221360564231873
#
# fear 0.5353845357894897
#
# surprise 0.97550368309021
#
# fear 0.6064674258232117
#
# surprise 0.989375114440918
#
# fear 0.6439198851585388
#
# anger 0.9885382652282715
#
# joy 0.9012791514396667
#
# surprise 0.9895245432853699
#
# joy 0.9778981804847717
#
# surprise 0.677111029624939
#
# anger 0.47305986285209656
#
# anger 0.5196641683578491
#
# surprise 0.9516010880470276
#
# surprise 0.7151407599449158
#
# surprise 0.9853273630142212
#
# surprise 0.9893611073493958
#
# love 0.8912416696548462
#
# anger 0.6438660621643066
#
# sadness 0.485383540391922
#
# anger 0.47307226061820984
#
# anger 0.8177513480186462
#
# joy 0.8088927268981934
#
# 300
# 257

# %%
test_corp = []
test_label = []
count = [0 for i in range(6)]
for i in range(len(test_corpus)):
    if test_corpus[i] not in test_corp:
        test_corp.append(test_corpus[i])
        test_label.append(test_labels[i])
    else:
        count[emotions.index(test_labels[i])] += 1
test_corpus = test_corp
test_labels = test_label
a = len(set(test_corpus))
print(len(test_corpus))
print(len(test_labels))
print(a)
for i in range(6):
    print(emotions[i],count[i])
# Out:
# 257
# 257
# 257
# sadness 0
# joy 0
# love 0
# anger 0
# fear 0
# surprise 0

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

X_train = []
with open('corpus.txt', encoding="utf8") as f:
    for line in f:
        X_train.append(line)
y_train = []
with open('labels.txt', encoding="utf8") as f:
    for line in f:
        y_train.append(line)
x_test = test_corpus
y_test = test_labels
# x_test = []
# with open('generated_sentences.txt', encoding="utf8") as f:
#     for line in f:
#         x_test.append(line)
# y_test = []
# with open('target_emotions.txt', encoding="utf8") as f:
#     for line in f:
#         y_test.append(line)
# Initialize TF-IDF vectorizer
# X_train, x_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

tfidf_vectorizer = TfidfVectorizer()

# Fit and transform on the training data
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)

# Transform the test data using the same vectorizer
X_test_tfidf = tfidf_vectorizer.transform(x_test)
# Define parameter grid for Grid Search
# param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['linear', 'rbf', 'poly', 'sigmoid']}
#
# # Initialize SVC
svc = SVC()
#
# # Perform Grid Search with 5-fold cross-validation
# grid_search = GridSearchCV(svc, param_grid, cv=5, n_jobs=-1)
# grid_search.fit(X_train_tfidf, y_train)
#
# # Get the best parameters
# best_params = grid_search.best_params_
# print("Best Parameters:", best_params)
# Train SVC with the best parameters obtained from Grid Search
best_svc = SVC(C=10, gamma=0.1,kernel='rbf')
best_svc.fit(X_train_tfidf, y_train)
# Predict using the trained model
y_pred = best_svc.predict(X_test_tfidf)
y_pred = [i.strip() for i in y_pred]

# print(y_test)
# Print classification report
print(classification_report(y_test, y_pred))

print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       1.00      0.55      0.71        47
#         fear       0.00      0.00      0.00         0
#          joy       0.00      0.00      0.00         0
#         love       0.00      0.00      0.00         0
#      sadness       0.00      0.00      0.00         0
#
#     accuracy                           0.55        47
#    macro avg       0.20      0.11      0.14        47
# weighted avg       1.00      0.55      0.71        47
#
# 0.5531914893617021
